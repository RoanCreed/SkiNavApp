# %%
import json
import uuid
import shapely
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, LineString
from geojson import Point, Feature, FeatureCollection, dump

dir = "/Users/sebastian/Documents/SkiNavApp/"

# %%
filename = "runs.geojson"
file = open(filename)
gdf_runs = gpd.read_file(file)

# %%
def get_name(data):
    json_file = json.loads(data)
    if len(json_file) > 0:
        name = json_file[0].get("properties").get("name")
    else:
        name = pd.NA
    return name

# %%
# filter Les Tois Vallées
gdf_runs["resort_name"] = gdf_runs.skiAreas.apply(lambda x: get_name(x))
gdf_runs = gdf_runs[gdf_runs.resort_name=="Les Trois Vallées"]
gdf_runs = gdf_runs[gdf_runs.elevationProfile.notnull()]

#gdf_runs.to_pickle(dir+"runs_les_trois_vallee.pkl")

# %%
filename = "lifts.geojson"
file = open(filename)
gdf_lifts = gpd.read_file(file)

# %%
# filter Les Tois Vallées
gdf_lifts["resort_name"] = gdf_lifts.skiAreas.apply(lambda x: get_name(x))
gdf_lifts = gdf_lifts[gdf_lifts.resort_name=="Les Trois Vallées"]

#gdf_lifts.to_pickle(dir+"lifts_les_trois_vallee.pkl")

# %%
gdf_runs = pd.read_pickle(dir+"runs_les_trois_vallee.pkl")
gdf_lifts = pd.read_pickle(dir+"lifts_les_trois_vallee.pkl")

# %%
# change to crs france UoM metric
features = ["id", "name", "resort_name", "connection_type", "difficulty",
            "duration", "distance", "geometry", "start", "end"]

gdf_runs = gdf_runs.to_crs("27561")
gdf_runs["uses"] = gdf_runs.uses.apply(lambda x: x[0])
gdf_runs["distance"] = gdf_runs.geometry.length
gdf_runs["start"] = gdf_runs.geometry.apply(lambda x: Point(x.coords[0]))
gdf_runs["end"] = gdf_runs.geometry.apply(lambda x: Point(x.coords[-1]))
gdf_runs["connection_type"] = "run"
gdf_runs["duration"] = gdf_runs["distance"] / 7 # 25km/h or 7m/s
gdf_runs = gdf_runs[gdf_runs.uses=="downhill"]
gdf_runs = gdf_runs[features]

# %%
# change to crs france UoM metric
gdf_lifts = gdf_lifts.to_crs("27561")
gdf_lifts["distance"] = gdf_lifts.geometry.length
gdf_lifts["start"] = gdf_lifts.geometry.apply(lambda x: Point(x.coords[0]))
gdf_lifts["end"] = gdf_lifts.geometry.apply(lambda x: Point(x.coords[-1]))
gdf_lifts["geometry"] = gdf_lifts.geometry.apply(lambda x: LineString([x.coords[0], x.coords[-1]]))
gdf_lifts["connection_type"] = "lift"
gdf_lifts = gdf_lifts.rename(columns={"liftType": "lift_type"})
gdf_lifts.head()
gdf_lifts["difficulty"] = "lift"
mean_speed = gdf_lifts[gdf_lifts["duration"].notnull()]["distance"].sum() / gdf_lifts[gdf_lifts["duration"].notnull()].duration.sum()
gdf_lifts["duration"] = np.where(gdf_lifts["duration"].isna(), (gdf_lifts["distance"] / mean_speed), gdf_lifts["duration"])
gdf_lifts = gdf_lifts[features]

# %%
data = pd.concat([gdf_lifts, gdf_runs])
#data

# %%
test_data = data.copy()
test_data = test_data[test_data["name"].isin(["Béranger", "Lac Blanc", "Tête Ronde", "Croissant",
                                    "Trolles", "Adrien Théaux", "Ardoises", "Boulevard Lauzes",
                                    "Dalles", "Stade", "Corniche", "Roc", "Christine",
                                    "Cascades", "Funitel Péclet", "Pionniers", "Plein Sud", "Vires",
                                    "Bleuets", "2 Combes", "Flocon", "Combe de Thorens"])]

#test_data = test_data[test_data["name"].isin(["3 Vallées", "Boulevard Goitschel", "Goitschel", "Chardons", "Pluviomètre"])]
test_data = test_data[~((test_data["name"].isin(["Stade"])) & (test_data.connection_type=="lift")) & (test_data.geometry.apply(lambda x: x.coords[0][1]) < -256000) & (test_data.geometry.apply(lambda x: x.coords[0][1]) > -260000) & (test_data.geometry.apply(lambda x: x.coords[0][0]) > 933000)]
test_data = test_data[~test_data.id.isin(["4c8d28e91232c0842a7ee27b6b688f83e36871c1", "8ca54533ba58833bb34bf182c41401bcc6ff564e"])] # remove duplicates

# %%
test_data.geometry.plot()
# Out:
# <Axes: >

# %%
start_points = test_data[["id", "name", "start", "difficulty", "duration", "connection_type"]].rename(columns={"start": "geometry"}).set_geometry("geometry")
start_points["point_type"] = "start"

end_points = test_data[["id", "name", "end", "difficulty", "duration", "connection_type"]].rename(columns={"end": "geometry"}).set_geometry("geometry")
end_points["point_type"] = "end"

start_end_points = pd.concat([start_points, end_points], axis=0)
#start_end_points

# %%
points = test_data.geometry.apply(lambda x: x.coords).rename("point").explode().reset_index().rename(columns={"index": "Index"})
test_data = test_data.reset_index().rename(columns={"index": "Index"})
points = points.merge(test_data[["id", "name", "Index", "difficulty", "duration", "connection_type"]], how="left", on="Index")
points = gpd.GeoDataFrame(points, geometry=[Point(x) for x in points.point])

# %%
points.crs = "epsg:27561"
points_wgs = points.to_crs(4326)
points_wgs["point"] = points_wgs.geometry.apply(lambda x: x.coords).rename("point").explode()
points_wgs = points_wgs.iloc[2:]
points_wgs

# %%
geo_json = {"tpye": "FeatureCollection",
            "features": [
                {"name": "Béranger",
                "geometry": {
                    "coordinates" : [x[:2] for x in points_wgs[points_wgs["name"]=="Béranger"].point.values]
                }},
                {"name": "Lac Blanc",
                "geometry": {
                    "coordinates" : [x[:2] for x in points_wgs[points_wgs["name"]=="Lac Blanc"].point.values]
                }},

            ]}

geo_json

# %%
with open(dir+'test_file.geojson', 'w') as f:
   dump(geo_json, f)

# %%
gpd.GeoDataFrame(points, geometry=[Point(x) for x in points.point]).plot()
# Out:
# <Axes: >

# %%
def get_center(nodes):
    x, y, z, n = [0, 0, 0, 0]
    for x_, y_, z_ in [n.coords[0] for n in nodes]:
        x += x_
        y += y_
        z += z_
        n += 1
    return ((x/n), (y/n), (z/n))


start_ids = []
end_ids = []
nodes_conn = []
buffer_zone = 25

for id, point_type, point_start_end, difficulty_se, duration_se, connection_type_se, name_se in list(zip(start_end_points.id, start_end_points.point_type, start_end_points.geometry, start_end_points.difficulty, start_end_points.duration, start_end_points.connection_type, start_end_points["name"])):
    conns = []
    coords = []
    features = []
    if point_type == "start" and id not in start_ids:
        start_ids.append(id)
        conns.append(id)
        coords.append(point_start_end)
        features.append({"id_connection": id,
                         "name": name_se,
                         "difficulty": difficulty_se,
                         "duration": duration_se,
                         "connection_type": connection_type_se})
        for id_conn, point, difficulty_p, duration_p, connection_type_p, name_p in list(zip(points.id, points.geometry, points.difficulty, points.duration, points.connection_type, points["name"])):
            if (id != id_conn and point.distance(point_start_end) < buffer_zone and id_conn not in conns):
                conns.append(id_conn)
                coords.append(point)
                features.append({"id_connection": id_conn,
                                 "name": name_p,
                                 "difficulty": difficulty_p,
                                 "duration": duration_p,
                                 "connection_type": connection_type_p})
                #start_ids.append(id_conn)


        id_node = str(uuid.uuid4())
        nodes_conn.append({"id_node": id_node,
                            "features": features,
                            "coords": get_center(coords)
        })   


    elif point_type == "end" and id not in end_ids:
        end_ids.append(id)
        conns.append(id)
        coords.append(point_start_end)
        features.append({"id_connection": id,
                         "name": name_se,
                         "difficulty": difficulty_se,
                         "duration": duration_se,
                         "connection_type": connection_type_se})
        for id_conn, point, difficulty_p, duration_p, connection_type_p, name_p in list(zip(points.id, points.geometry, points.difficulty, points.duration, points.connection_type, points["name"])):
            if (id != id_conn and point.distance(point_start_end) < buffer_zone and id_conn not in conns):
                conns.append(id_conn)
                coords.append(point)
                features.append({"id_connection": id_conn,
                                 "name": name_p,
                                 "difficulty": difficulty_p,
                                 "duration": duration_p,
                                 "connection_type": connection_type_p})
                #end_ids.append(id_conn)

        id_node = str(uuid.uuid4())
        nodes_conn.append({"id_node": id_node, # "id_connection": conns,
                            "features": features,
                            "coords": get_center(coords)
        })

    
  
len(nodes_conn)
# Out:
# 228

# %%
fig, ax = plt.subplots(figsize=(10,12))
test_data.geometry.plot(ax=ax)
start_end_points.geometry.plot(ax=ax, color="lightgreen")
gpd.GeoDataFrame(nodes_conn, geometry=[Point(x.get("coords")) for x in nodes_conn]).plot(ax=ax, color="red")
# Out:
# <Axes: >

# %%
def get_center(nodes):
    x, y, z, n = [0, 0, 0, 0]
    for x_, y_, z_ in [n for n in nodes]:
        x += x_
        y += y_
        z += z_
        n += 1
    return ((x/n), (y/n), (z/n))

def unique_connection(data):
    connections = []
    output = []
    for i in data:
        if i.get("id_connection") not in connections:
            connections.append(i.get("id_connection"))
            output.append(i)
    return output

nodes_no_duplicates = []
discared_nodes = []
buffer_zone = 50

for node in nodes_conn:
    if node.get("id_node") not in discared_nodes:
        duplicate = False
        duplactes_connections = []
        duplactes_coords = []
        for n in nodes_conn:
            if node.get("id_node") != n.get("id_node") and shapely.points(node.get("coords")).distance(shapely.points(n.get("coords"))) < buffer_zone:
                duplactes_connections.append(n.get("features")) 
                duplactes_coords.append(n.get("coords"))
                discared_nodes.append(n.get("id_node"))
                duplicate = True

        if duplicate == True:
            nodes_no_duplicates.append({"id_node": node.get("id_node"),
                                        "features": unique_connection(node.get("features") + sum(duplactes_connections, [])),
                                        "coords": get_center([node.get("coords")] + duplactes_coords)})

        elif duplicate == False:
            nodes_no_duplicates.append({"id_node": node.get("id_node"),
                                        "features": node.get("features"),
                                        "coords": node.get("coords")})

len(nodes_no_duplicates)
# Out:
# 123

# %%
#[Point(x.get("coords")) for x in nodes_conn]
fig, ax = plt.subplots(figsize=(10,12))
test_data.geometry.plot(ax=ax)
start_end_points.geometry.plot(ax=ax, color="lightgreen")
gpd.GeoDataFrame(nodes_no_duplicates, geometry=[Point(x.get("coords")) for x in nodes_no_duplicates]).plot(ax=ax, color="red")
# Out:
# <Axes: >

# %%
smooth = 2
nodes = []

for node in nodes_no_duplicates:
    features = []
    id_connected_nodes = []
    for feature in node.get("features"):
        conns_candidate = []
        distances = {}
        for n in nodes_no_duplicates:
            if node.get("id_node") != n.get("id_node") and feature.get("id_connection") in [x.get("id_connection") for x in n.get("features")] and (node.get("coords")[2] + smooth) >= n.get("coords")[2] and feature.get("connection_type") == "run":
                conns_candidate.append(n)

            elif node.get("id_node") != n.get("id_node") and feature.get("id_connection") in [x.get("id_connection") for x in n.get("features")] and (node.get("coords")[2] + smooth) <= n.get("coords")[2] and feature.get("connection_type") == "lift":
                conns_candidate.append(n)

        for candiate in conns_candidate:
            distances[candiate.get("id_node")] = shapely.points(node.get("coords")).distance(shapely.points(candiate.get("coords")))

        if len(conns_candidate) > 0:
            closest_node = min(distances, key=distances.get)
            if closest_node not in id_connected_nodes:
                id_connected_nodes.append([x.get("id_node") for x in conns_candidate if x.get("id_node") == closest_node][0])
                features.append(feature)
                
    nodes.append({"id_node": node.get("id_node"),
                  "features": features,
                  "id_connected_nodes": id_connected_nodes,
                  "coords": node.get("coords")})

# %%
nodes
# Out:
# [{'id_node': '06570f28-391c-4440-b62d-9fea23ba4216',
#   'features': [{'id_connection': '11effb194edfdc7596d7fbcc4d28fe2fa13dee65',
#     'name': 'Cascades',
#     'difficulty': 'lift',
#     'duration': 285.0,
#     'connection_type': 'lift'},
#    {'id_connection': 'befbd0de589264db6d2cb27373a556246724c286',
#     'name': 'Campagnols',
#     'difficulty': 'lift',
#     'duration': 190.0,
#     'connection_type': 'lift'},
#    {'id_connection': 'cf0cd1dbb3ab10e500d30c5c51fd628db7744d28',
#     'name': 'Combe de Thorens',
#     'difficulty': 'novice',
#     'duration': 285.6291194771849,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['847a48e6-ab13-4459-91bf-72f2ce5ba1fc',
#    'dbaa3ebc-c77a-472f-9b5a-e5c05abea177',
#    'a0bd658a-d93f-4901-b347-37e2ac5b2156'],
#   'coords': (933334.166726292, -258429.87108078567, 2250.809492063492)},
#  {'id_node': 'd4943d79-0f93-41c8-a590-2f639c0c24f7',
#   'features': [{'id_connection': 'c167ad3a1dc0944dabe1e33a9a569d437f03bbd3',
#     'name': 'Portette',
#     'difficulty': 'lift',
#     'duration': 441.5753593664326,
#     'connection_type': 'lift'},
#    {'id_connection': 'cf0cd1dbb3ab10e500d30c5c51fd628db7744d28',
#     'name': 'Combe de Thorens',
#     'difficulty': 'novice',
#     'duration': 285.6291194771849,
#     'connection_type': 'run'},
#    {'id_connection': 'd5ce53fea2a394234bd87a8880e19354d3151e19',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 13.02710363088699,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['9954b434-1c49-409a-ae78-044c18cd3e7f',
#    'b4a639ef-03c8-447a-8850-b3dfc9dafff4',
#    'a067dec8-e9d1-42a2-81c8-0d9d6ecc9f53'],
#   'coords': (933820.4085418334, -259370.34927295838, 2351.2333333333336)},
#  {'id_node': 'a067dec8-e9d1-42a2-81c8-0d9d6ecc9f53',
#   'features': [{'id_connection': 'd8d05e7feae56f52c847ab4189f99de9990f841d',
#     'name': 'Moraine',
#     'difficulty': 'lift',
#     'duration': 408.0,
#     'connection_type': 'lift'}],
#   'id_connected_nodes': ['ad8c91ba-429a-42b3-8bfc-eb41f53ac29c'],
#   'coords': (933821.77268025, -259266.04298625002, 2344.5625)},
#  {'id_node': '9c173425-99b8-404d-93c0-9e990b2c84fb',
#   'features': [{'id_connection': 'af3bce64bc75415b0490f9c90ac08299e5ced573',
#     'name': 'Funitel 3 Vallées',
#     'difficulty': 'lift',
#     'duration': 112.0,
#     'connection_type': 'lift'},
#    {'id_connection': 'fe18538c35a58ea82161f50c8ac5e7ba206af63f',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 12.274445283203068,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['0f519bca-1d16-49ea-86ee-8a157f0482dc',
#    '843f6728-85b4-466c-ba8e-10062091562f'],
#   'coords': (933940.7180358134, -257324.27867660666, 2533.5739999999996)},
#  {'id_node': '6873780c-10c1-4e54-af9a-7d37f6bae29e',
#   'features': [{'id_connection': '7d2f5218911e9c0157058ab41bcc0baecd9d1b92',
#     'name': 'Pionniers',
#     'difficulty': 'lift',
#     'duration': 268.0,
#     'connection_type': 'lift'},
#    {'id_connection': 'c2a5bf7eae88429074325a9ed025cbc3518c508f',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 12.587965413052688,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['1bd8454c-1c11-4512-9950-f18d5d7985e6',
#    '4ac1da52-f595-48d0-8e10-18f5366765a9'],
#   'coords': (933694.95855225, -258408.62052345835, 2282.3770833333333)},
#  {'id_node': '4c888ce5-3686-4cca-ac89-e726cad72c16',
#   'features': [{'id_connection': '633a74fa26e2f5333380f1e3d25e621b2681918c',
#     'name': 'Castor Pollux',
#     'difficulty': 'lift',
#     'duration': 190.0,
#     'connection_type': 'lift'},
#    {'id_connection': 'a37f13a1bd0860fac7e6427a33ad70b085c7899a',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 75.90555141897251,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['94a9cf65-abb1-445e-a29f-64e1aace3ae9',
#    'dbaa3ebc-c77a-472f-9b5a-e5c05abea177'],
#   'coords': (933656.3238412222, -258377.43320988887, 2279.09)},
#  {'id_node': '0c4f8ac1-26ad-46a6-b949-3d43573ca69d',
#   'features': [{'id_connection': '128ad3a080b7d7d918e8f07fffc8c11fa80d3c4d',
#     'name': 'Musaraigne',
#     'difficulty': 'lift',
#     'duration': 185.0,
#     'connection_type': 'lift'}],
#   'id_connected_nodes': ['072dbe8f-e00d-4fa9-b1d2-c1c04b60dc01'],
#   'coords': (933147.6850163332, -258338.59094766667, 2235.4933333333333)},
#  {'id_node': '715356a3-6eae-44cd-ae7d-7a67f62896fa',
#   'features': [{'id_connection': 'f5bd0831bd8b7a3724442729195fbfe2aa291213',
#     'name': 'Lac Blanc',
#     'difficulty': 'lift',
#     'duration': 485.00389513358977,
#     'connection_type': 'lift'},
#    {'id_connection': '15cd1be36dd3a560a8c515f3e03f6e92345ce47c',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 20.019871548170702,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['ad10d131-f89f-4d01-a2ff-70148e16a831',
#    '4ac1da52-f595-48d0-8e10-18f5366765a9'],
#   'coords': (933665.916416988, -258543.0337435476, 2284.7390476190476)},
#  {'id_node': 'f118c07c-af83-4c7c-a69d-ba34785021c2',
#   'features': [{'id_connection': 'dd7dbf17741e75c3decec2c7aa2770f792fad61a',
#     'name': 'Funitel Péclet',
#     'difficulty': 'lift',
#     'duration': 720.0,
#     'connection_type': 'lift'},
#    {'id_connection': 'e8645ce4bd40c276a6392fff42fa3ef466617a25',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 13.464108343066398,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['f4b31f5a-9399-4e6a-ab29-d927efcedb2b',
#    'a0bd658a-d93f-4901-b347-37e2ac5b2156'],
#   'coords': (933187.4836842499, -258429.31340425, 2240.92)},
#  {'id_node': '2b362fa7-4dea-43a6-bca3-7dd28d3776c1',
#   'features': [{'id_connection': '9dc5fccc322f4021a7e996ecf8c33c1d686aff93',
#     'name': 'Pluviomètre',
#     'difficulty': 'easy',
#     'duration': 71.56914672139426,
#     'connection_type': 'run'},
#    {'id_connection': '3858b5afac0e95eb16b7f5350e0c2bfd6573dea8',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 20.05421073967611,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['072dbe8f-e00d-4fa9-b1d2-c1c04b60dc01',
#    '06570f28-391c-4440-b62d-9fea23ba4216'],
#   'coords': (933452.1694267084, -258365.40648991667, 2263.5220833333333)},
#  {'id_node': '2de249fd-5357-4f76-900e-cc36480a0a70',
#   'features': [{'id_connection': '1486ebe41ff7fe965730e8a42718f1d5959cd723',
#     'name': None,
#     'difficulty': 'lift',
#     'duration': 5.455703960231329,
#     'connection_type': 'lift'}],
#   'id_connected_nodes': ['edfb06c8-25eb-4375-bde9-5a8bd7ebe864'],
#   'coords': (933545.5196705, -258394.767398, 2268.37)},
#  {'id_node': '50c5ca6a-16b4-4314-b30a-bb8f6136f595',
#   'features': [{'id_connection': 'ef06e7a098ea2a00b6241e44792146161c92bee1',
#     'name': 'Boulevard Goitschel',
#     'difficulty': 'easy',
#     'duration': 71.34480613157379,
#     'connection_type': 'run'},
#    {'id_connection': 'eece93f1f5d556165915c40260fcd4acd173f2d4',
#     'name': 'Goitschel',
#     'difficulty': 'advanced',
#     'duration': 118.81767391528855,
#     'connection_type': 'run'},
#    {'id_connection': '73802c70540e1f32b62e0996b18870cdca92349f',
#     'name': 'Chardons',
#     'difficulty': 'intermediate',
#     'duration': 183.71360224645238,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['aab33cbf-7e42-4fe9-9fac-411623e8d61d',
#    'e977e258-544b-4b16-b3f7-c51864b98c81',
#    '0f519bca-1d16-49ea-86ee-8a157f0482dc'],
#   'coords': (933954.425493, -256507.810571, 2804.08)},
#  {'id_node': 'aab33cbf-7e42-4fe9-9fac-411623e8d61d',
#   'features': [{'id_connection': 'b6b8ce716d4f254e631d320399cca0a1b596f40c',
#     'name': 'Lac de la Chambre',
#     'difficulty': 'easy',
#     'duration': 601.5024085247088,
#     'connection_type': 'run'},
#    {'id_connection': '12dbf578b4ff6409e4a345da36cd018281998937',
#     'name': 'Pluviomètre',
#     'difficulty': 'easy',
#     'duration': 316.3754759896956,
#     'connection_type': 'run'},
#    {'id_connection': 'f61b29273a8cd2ada82e64829c7f311adffb5075',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 58.37465158186599,
#     'connection_type': 'run'},
#    {'id_connection': 'dfe0a6d65edd20a2e6bfa7e3e5e7d89e7e07a747',
#     'name': 'Boulevard de la Lance',
#     'difficulty': 'intermediate',
#     'duration': 119.75590896895157,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['7f0fbd5c-2197-488a-b9e7-88ec53834595',
#    '4e547be7-4075-4a92-8f81-277da8860582',
#    '4b57385b-ce7c-4bac-bfdb-21a520c839b1',
#    'b3308276-85f1-4ee6-a64b-2b4a390aeec2'],
#   'coords': (933495.554418, -256334.34477599998, 2773.08)},
#  {'id_node': 'efd75183-16f4-46eb-9bff-033f90f85d1a',
#   'features': [{'id_connection': '497d824a7c350f3c63ae66eb89f4cf145e16d6f3',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 18.06990946919125,
#     'connection_type': 'run'},
#    {'id_connection': 'aef83b4b86635dfc8fd2648f1fc0118258b3468c',
#     'name': 'Chalets',
#     'difficulty': 'easy',
#     'duration': 192.49163853097676,
#     'connection_type': 'run'},
#    {'id_connection': '33d92b2cbbd0e98974f3fafa771d1f3aab5a1cce',
#     'name': 'Traversée Deux Lacs',
#     'difficulty': 'novice',
#     'duration': 106.75676203919343,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['d6c9322e-10dc-47a7-bc1f-a22e97586362',
#    '0cba62a6-51a6-4e40-8912-e7badb57650d',
#    '8c135b95-4761-4ad7-8295-bdb1a5bb3b00'],
#   'coords': (933104.7973787918, -259464.03879925003, 2449.2883333333334)},
#  {'id_node': '560bfa85-bced-4a2a-99cf-2230497602f6',
#   'features': [{'id_connection': '1841068a3096e585f54dceb9acd62f5c769df22a',
#     'name': 'Altiport',
#     'difficulty': 'easy',
#     'duration': 88.00809327607024,
#     'connection_type': 'run'},
#    {'id_connection': 'e9de25b386cde90d965a372b15625438a7afc1c1',
#     'name': 'Linotte',
#     'difficulty': 'easy',
#     'duration': 67.56948446897806,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['d4f4dd04-f8f5-4402-a624-fd03b56b8e2a',
#    '2e445be5-9578-4e7f-9cf8-6bd9c78bad3c'],
#   'coords': (933034.865808, -259881.751639, 2487.55)},
#  {'id_node': '847a48e6-ab13-4459-91bf-72f2ce5ba1fc',
#   'features': [{'id_connection': 'f8b504cf58e9643370192bc078ff603cb80efbc9',
#     'name': '2 Combes',
#     'difficulty': 'novice',
#     'duration': 196.07908599243305,
#     'connection_type': 'run'},
#    {'id_connection': '04ec136065b5cf4a00a353745d389a1139a07674',
#     'name': 'Ardoises',
#     'difficulty': 'intermediate',
#     'duration': 43.096751283503714,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['5ceaaec8-26cd-42e9-8fc8-b673392d1b38',
#    'f8a13995-b740-4898-aad7-9bc0d034727b'],
#   'coords': (934695.1918063125, -258830.76297975003, 2559.2775)},
#  {'id_node': 'f075f26a-5066-49b0-9f30-fb85c42e17af',
#   'features': [{'id_connection': 'f61b29273a8cd2ada82e64829c7f311adffb5075',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 58.37465158186599,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['aab33cbf-7e42-4fe9-9fac-411623e8d61d'],
#   'coords': (933548.651009, -256522.661304, 2773.95)},
#  {'id_node': 'f4b31f5a-9399-4e6a-ab29-d927efcedb2b',
#   'features': [{'id_connection': '20432332cc7a714c671e4105235d1ce2a757f8cc',
#     'name': 'Tête Ronde',
#     'difficulty': 'easy',
#     'duration': 371.564196293215,
#     'connection_type': 'run'},
#    {'id_connection': '0602c22d0ee93ab4320c45ce4d9d3cea5b49f867',
#     'name': 'Béranger',
#     'difficulty': 'intermediate',
#     'duration': 330.9113378839116,
#     'connection_type': 'run'},
#    {'id_connection': '327610f1acb523e9c5c26e69b849fb180f9939b7',
#     'name': 'Lac Blanc',
#     'difficulty': 'intermediate',
#     'duration': 210.00966162612798,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['46250c08-2014-4c7e-bed9-fed03921dd16',
#    'e45f176c-77b0-4e0f-bbf1-baddc3e3d366',
#    '5baadc6a-d3cb-458f-b880-1fa0ff202570'],
#   'coords': (936247.3726252834, -258688.03281603332, 2921.190583333333)},
#  {'id_node': 'eb9de5df-38ed-4449-be92-0ed6b44374a2',
#   'features': [{'id_connection': '1744840abdd56aca2391499c8df2c252f1ca31ae',
#     'name': 'Plein Sud',
#     'difficulty': 'easy',
#     'duration': 257.6864939105756,
#     'connection_type': 'run'},
#    {'id_connection': '49c0da00479c6f245e3cd7d2e72b31a4d6c62f67',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 41.31404929841522,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['e977e258-544b-4b16-b3f7-c51864b98c81',
#    'fefc089a-92eb-4d85-9bd3-36db9574c85c'],
#   'coords': (934141.0488705, -257239.2649895, 2578.0)},
#  {'id_node': '862c50b2-b5f2-4b0d-8e6e-e13b7152ae3b',
#   'features': [{'id_connection': 'a37f13a1bd0860fac7e6427a33ad70b085c7899a',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 75.90555141897251,
#     'connection_type': 'run'},
#    {'id_connection': '1744840abdd56aca2391499c8df2c252f1ca31ae',
#     'name': 'Plein Sud',
#     'difficulty': 'easy',
#     'duration': 257.6864939105756,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['52685ee0-d917-4656-97aa-24fd14954edb',
#    '0ee893bc-97bb-4a58-ace9-b9ab28fa0d09'],
#   'coords': (933701.8506390001, -257966.1085885, 2332.72)},
#  {'id_node': '83faac15-8f26-468e-87a6-c14ba6b9181d',
#   'features': [{'id_connection': '7114a9d26c0ded42d29bbca523a5a57d42bae4c2',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 47.962257870088614,
#     'connection_type': 'run'},
#    {'id_connection': '1744840abdd56aca2391499c8df2c252f1ca31ae',
#     'name': 'Plein Sud',
#     'difficulty': 'easy',
#     'duration': 257.6864939105756,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['360cfb35-c079-43d7-a19c-b77dc40963fc',
#    'a358814d-3b4c-4e53-aa31-e469dc387c77'],
#   'coords': (933685.454527, -257656.791059, 2431.49)},
#  {'id_node': 'b3308276-85f1-4ee6-a64b-2b4a390aeec2',
#   'features': [{'id_connection': 'e295e1fee4fad60521bfad7e5c0efb50b3571787',
#     'name': '4 Vents',
#     'difficulty': 'intermediate',
#     'duration': 188.18659371986328,
#     'connection_type': 'run'},
#    {'id_connection': 'dfe0a6d65edd20a2e6bfa7e3e5e7d89e7e07a747',
#     'name': 'Boulevard de la Lance',
#     'difficulty': 'intermediate',
#     'duration': 119.75590896895157,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['9f200f82-f2f9-4115-8e87-a9d95ce8a058',
#    '7388d166-3fde-48b7-a26a-57d3dfbc1ec0'],
#   'coords': (933296.058486, -256186.942491, 2760.03)},
#  {'id_node': '797ed540-d320-47d6-b20b-81f05dbd5592',
#   'features': [{'id_connection': '5a8e7b947edaa619fe03e2bce9326a9fa8fdfa33',
#     'name': 'Trolles',
#     'difficulty': 'intermediate',
#     'duration': 26.396407333821315,
#     'connection_type': 'run'},
#    {'id_connection': 'a1ce835ad3b70417de259f36d9e752aee5a3c45f',
#     'name': 'Adrien Théaux',
#     'difficulty': 'intermediate',
#     'duration': 223.57982463790765,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['f8a13995-b740-4898-aad7-9bc0d034727b',
#    '99c702a9-962d-4143-9d45-63c84d67446d'],
#   'coords': (934886.847893, -258387.58477850002, 2579.185)},
#  {'id_node': '247ba364-5f37-4257-a0a9-3535ecd5a833',
#   'features': [{'id_connection': 'de62cf329428aa5ea0c488305855c280792d6119',
#     'name': 'Hermine',
#     'difficulty': 'easy',
#     'duration': 223.95997630712594,
#     'connection_type': 'run'},
#    {'id_connection': 'e9de25b386cde90d965a372b15625438a7afc1c1',
#     'name': 'Linotte',
#     'difficulty': 'easy',
#     'duration': 67.56948446897806,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['d6c9322e-10dc-47a7-bc1f-a22e97586362',
#    'efd75183-16f4-46eb-9bff-033f90f85d1a'],
#   'coords': (933092.766559, -259724.516715, 2475.5)},
#  {'id_node': '4e547be7-4075-4a92-8f81-277da8860582',
#   'features': [{'id_connection': '3b1c4b176d7ebba120043595b7aeace91f64abeb',
#     'name': 'Pluviomètre',
#     'difficulty': 'easy',
#     'duration': 35.29857129226347,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['0cfe13fc-b16b-40be-8e15-4928ad8275e8'],
#   'coords': (933690.882094, -256509.840478, 2772.43)},
#  {'id_node': 'e14bf599-ea9d-4a26-a1f5-6281aa8d2caf',
#   'features': [{'id_connection': '91be571ebbe240154f1e9df5ab785cd1b4d27134',
#     'name': None,
#     'difficulty': 'intermediate',
#     'duration': 30.495835326409576,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['9f200f82-f2f9-4115-8e87-a9d95ce8a058'],
#   'coords': (933268.294836, -256381.111253, 2722.11)},
#  {'id_node': '11c83c82-6f02-484a-8531-0db2cd1c2e0e',
#   'features': [{'id_connection': 'd172da53602b44edf7714b27e92fcf087ddbf398',
#     'name': 'Voie de la Boucle',
#     'difficulty': 'easy',
#     'duration': 36.70842631281597,
#     'connection_type': 'run'},
#    {'id_connection': 'db7c59fa0bce780b98aed324e8a73b9aee44d755',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 15.80319929807791,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['381354cb-9a0e-4109-a09f-bbba49bcd935',
#    '407235cd-cbf5-4e88-b51e-385ace63e1d8'],
#   'coords': (933291.12246675, -258081.02293633335, 2286.6924999999997)},
#  {'id_node': '0ee893bc-97bb-4a58-ace9-b9ab28fa0d09',
#   'features': [{'id_connection': '0a08b41aa177470635ed024b47f553f880ccd33c',
#     'name': 'Plein Sud',
#     'difficulty': 'easy',
#     'duration': 102.14281338460869,
#     'connection_type': 'run'},
#    {'id_connection': '1744840abdd56aca2391499c8df2c252f1ca31ae',
#     'name': 'Plein Sud',
#     'difficulty': 'easy',
#     'duration': 257.6864939105756,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['a5e2db65-4ba9-472d-9bd4-619872b7d1a0',
#    'b1bd1257-18f7-4978-8f91-96d9763ed061'],
#   'coords': (933521.320571, -258010.775981, 2326.27)},
#  {'id_node': 'a5e2db65-4ba9-472d-9bd4-619872b7d1a0',
#   'features': [{'id_connection': '9dc5fccc322f4021a7e996ecf8c33c1d686aff93',
#     'name': 'Pluviomètre',
#     'difficulty': 'easy',
#     'duration': 71.56914672139426,
#     'connection_type': 'run'},
#    {'id_connection': '0a08b41aa177470635ed024b47f553f880ccd33c',
#     'name': 'Plein Sud',
#     'difficulty': 'easy',
#     'duration': 102.14281338460869,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['11c83c82-6f02-484a-8531-0db2cd1c2e0e',
#    '407235cd-cbf5-4e88-b51e-385ace63e1d8'],
#   'coords': (933271.6612836667, -258023.69448608335, 2294.838333333333)},
#  {'id_node': '1bd8454c-1c11-4512-9950-f18d5d7985e6',
#   'features': [{'id_connection': 'dca4a5b46f4523559d661bfa1e6e9572a9f41ce0',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 60.020400448849344,
#     'connection_type': 'run'},
#    {'id_connection': '1744840abdd56aca2391499c8df2c252f1ca31ae',
#     'name': 'Plein Sud',
#     'difficulty': 'easy',
#     'duration': 257.6864939105756,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['0f519bca-1d16-49ea-86ee-8a157f0482dc',
#    'fefc089a-92eb-4d85-9bd3-36db9574c85c'],
#   'coords': (933999.350111514, -257295.10827183336, 2545.2463888888888)},
#  {'id_node': 'e977e258-544b-4b16-b3f7-c51864b98c81',
#   'features': [{'id_connection': 'bfb2cf764aa3158a21be101792af7aee4b4adf20',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 23.95439016754696,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['1bd8454c-1c11-4512-9950-f18d5d7985e6'],
#   'coords': (934028.3760328335, -257252.68832283336, 2554.991666666667)},
#  {'id_node': 'edfb06c8-25eb-4375-bde9-5a8bd7ebe864',
#   'features': [{'id_connection': '0723dae28099e548f5c8303cd5e6472d71e09e2d',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 20.57187996809066,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['2b362fa7-4dea-43a6-bca3-7dd28d3776c1'],
#   'coords': (933579.5824635001, -258389.153308, 2271.5699999999997)},
#  {'id_node': '8fb47ff5-950b-4f5c-a3b8-f9f561bb359f',
#   'features': [{'id_connection': '6d60993e5970d2f68a49ae36676f3970977720fd',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 23.164671720100703,
#     'connection_type': 'run'},
#    {'id_connection': 'cf0cd1dbb3ab10e500d30c5c51fd628db7744d28',
#     'name': 'Combe de Thorens',
#     'difficulty': 'novice',
#     'duration': 285.6291194771849,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['61f8c793-d30e-4ac7-8e0f-39733e9919cf',
#    '4e446617-97e3-48f6-87fb-9686ebd39360'],
#   'coords': (933033.7578071668, -258387.93066922223, 2216.3133333333335)},
#  {'id_node': '3614fa53-0cd2-4a3b-9cce-5f960e138f1b',
#   'features': [{'id_connection': '99c505c80ee7d459c0816bb0356acbd589f2ee11',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 24.061522807757626,
#     'connection_type': 'run'},
#    {'id_connection': 'fbe63b6d2cce9173b35d8d844ffa49f5362896fa',
#     'name': 'Retour Sud',
#     'difficulty': 'easy',
#     'duration': 70.15551379793868,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['6742705a-4cc3-4c56-8085-331af2c08fb3',
#    'aa33da10-5b4f-48cc-a22f-be643298f9ce'],
#   'coords': (933866.5489970001, -257972.17728950002, 2352.955)},
#  {'id_node': 'a0bd658a-d93f-4901-b347-37e2ac5b2156',
#   'features': [{'id_connection': 'e8645ce4bd40c276a6392fff42fa3ef466617a25',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 13.464108343066398,
#     'connection_type': 'run'},
#    {'id_connection': 'cf0cd1dbb3ab10e500d30c5c51fd628db7744d28',
#     'name': 'Combe de Thorens',
#     'difficulty': 'novice',
#     'duration': 285.6291194771849,
#     'connection_type': 'run'},
#    {'id_connection': '66e1131dc689da599799d68d83deb89930319192',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 25.848466177137926,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['f118c07c-af83-4c7c-a69d-ba34785021c2',
#    'ee0579be-a062-43e9-a7f8-dd94d066d75f',
#    '0c4f8ac1-26ad-46a6-b949-3d43573ca69d'],
#   'coords': (933232.6950008888, -258386.27479766667, 2242.0455555555554)},
#  {'id_node': '5e103bba-f403-496f-8290-e313c4b62011',
#   'features': [{'id_connection': 'e175be38c168d85780154d8b66cc1ce0fcd30c65',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 61.421354970124426,
#     'connection_type': 'run'},
#    {'id_connection': 'b2cbfe63c2b8626311d669bc02a94b0bee680e1d',
#     'name': 'Roc',
#     'difficulty': 'novice',
#     'duration': 81.40222165057398,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['4e86065b-7cba-4b5f-9af2-1e4c5d5b7973',
#    '1e82a343-1df8-411e-a815-293e1c3c73e2'],
#   'coords': (933991.6424344999, -258538.29313575, 2327.09)},
#  {'id_node': '072dbe8f-e00d-4fa9-b1d2-c1c04b60dc01',
#   'features': [{'id_connection': '9ee59be298c9392ba9a0e8a00a033b57288f67cd',
#     'name': 'Musaraigne',
#     'difficulty': 'novice',
#     'duration': 32.88028652058059,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['0c4f8ac1-26ad-46a6-b949-3d43573ca69d'],
#   'coords': (933375.0322507501, -258365.46655625, 2255.86)},
#  {'id_node': '5d30d5c1-7575-4ebb-b91f-0a65816706c9',
#   'features': [{'id_connection': 'cf0cd1dbb3ab10e500d30c5c51fd628db7744d28',
#     'name': 'Combe de Thorens',
#     'difficulty': 'novice',
#     'duration': 285.6291194771849,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['f7d2d19b-7e30-42cd-86cc-1d4a7f81f67d'],
#   'coords': (933777.028527, -259576.40079, 2381.82)},
#  {'id_node': 'a358814d-3b4c-4e53-aa31-e469dc387c77',
#   'features': [{'id_connection': 'fbe63b6d2cce9173b35d8d844ffa49f5362896fa',
#     'name': 'Retour Sud',
#     'difficulty': 'easy',
#     'duration': 70.15551379793868,
#     'connection_type': 'run'},
#    {'id_connection': '1744840abdd56aca2391499c8df2c252f1ca31ae',
#     'name': 'Plein Sud',
#     'difficulty': 'easy',
#     'duration': 257.6864939105756,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['aa33da10-5b4f-48cc-a22f-be643298f9ce',
#    'f8eef11d-4080-4907-bc4b-d3480f311523'],
#   'coords': (933665.519185, -257730.595205, 2411.23)},
#  {'id_node': '94a9cf65-abb1-445e-a29f-64e1aace3ae9',
#   'features': [{'id_connection': '7f77f2e0a25200ca4a0dc6bea37f9a68c936f789',
#     'name': 'Voie Lactée',
#     'difficulty': 'novice',
#     'duration': 34.759287040557005,
#     'connection_type': 'run'},
#    {'id_connection': 'a37f13a1bd0860fac7e6427a33ad70b085c7899a',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 75.90555141897251,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['6274005e-08b6-4e6a-9ee4-ae0527f822c2',
#    '4c888ce5-3686-4cca-ac89-e726cad72c16'],
#   'coords': (933688.898938725, -258159.32475630002, 2312.973)},
#  {'id_node': '126bf4e2-7a04-4fed-a648-0ffeb2f92683',
#   'features': [{'id_connection': 'f9214995594b42205bf550a2ea2433ae66a4dbd0',
#     'name': 'Christine',
#     'difficulty': 'intermediate',
#     'duration': 270.20419741313907,
#     'connection_type': 'run'},
#    {'id_connection': '20432332cc7a714c671e4105235d1ce2a757f8cc',
#     'name': 'Tête Ronde',
#     'difficulty': 'easy',
#     'duration': 371.564196293215,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['df07ef11-008e-423f-b06b-2284d467d8a4',
#    '661602ee-c2c1-40f6-8c08-7bb6bf0b0b04'],
#   'coords': (935756.194998, -259128.370053, 2854.54)},
#  {'id_node': 'abcd4a74-3f9a-4159-a210-87eec8ca3317',
#   'features': [{'id_connection': '6acb68b760f81ca552ed986da7908b70d14fc098',
#     'name': 'Stade',
#     'difficulty': 'advanced',
#     'duration': 151.65462093869866,
#     'connection_type': 'run'},
#    {'id_connection': 'a1ce835ad3b70417de259f36d9e752aee5a3c45f',
#     'name': 'Adrien Théaux',
#     'difficulty': 'intermediate',
#     'duration': 223.57982463790765,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['95bc412f-4707-461b-84b1-ad75ab4b75fa',
#    '797ed540-d320-47d6-b20b-81f05dbd5592'],
#   'coords': (935222.470154, -258326.898413, 2685.56)},
#  {'id_node': '1f278abd-3a58-4c13-bb36-f86ddd98a9d0',
#   'features': [{'id_connection': 'b2cbfe63c2b8626311d669bc02a94b0bee680e1d',
#     'name': 'Roc',
#     'difficulty': 'novice',
#     'duration': 81.40222165057398,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['5e103bba-f403-496f-8290-e313c4b62011'],
#   'coords': (934167.9220141876, -258563.2909366875, 2360.3943750000003)},
#  {'id_node': '8c135b95-4761-4ad7-8295-bdb1a5bb3b00',
#   'features': [{'id_connection': '459923b8eeac4b292046e131c0066227afe02e81',
#     'name': 'Espace Junior',
#     'difficulty': 'novice',
#     'duration': 153.02294921730757,
#     'connection_type': 'run'},
#    {'id_connection': '33d92b2cbbd0e98974f3fafa771d1f3aab5a1cce',
#     'name': 'Traversée Deux Lacs',
#     'difficulty': 'novice',
#     'duration': 106.75676203919343,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['715356a3-6eae-44cd-ae7d-7a67f62896fa',
#    '9f580e03-49cf-4eb2-961e-d46774655726'],
#   'coords': (933449.381598, -259550.87022, 2423.04)},
#  {'id_node': '2e445be5-9578-4e7f-9cf8-6bd9c78bad3c',
#   'features': [{'id_connection': '180c6fffcd5f9e2ecd2ebec7756d1a0e4959c154',
#     'name': 'Arolles',
#     'difficulty': 'advanced',
#     'duration': 101.36550542226016,
#     'connection_type': 'run'},
#    {'id_connection': 'e9de25b386cde90d965a372b15625438a7afc1c1',
#     'name': 'Linotte',
#     'difficulty': 'easy',
#     'duration': 67.56948446897806,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['62da9c9f-75f4-402b-ae40-1f5c4e1d14f1',
#    '247ba364-5f37-4257-a0a9-3535ecd5a833'],
#   'coords': (933075.580901, -259797.930281, 2482.49)},
#  {'id_node': '5ceaaec8-26cd-42e9-8fc8-b673392d1b38',
#   'features': [{'id_connection': '0f97ef46ec9cef8503ba11c87a727bea6be0d4fe',
#     'name': 'Dalles',
#     'difficulty': 'easy',
#     'duration': 146.39134557386635,
#     'connection_type': 'run'},
#    {'id_connection': 'f8b504cf58e9643370192bc078ff603cb80efbc9',
#     'name': '2 Combes',
#     'difficulty': 'novice',
#     'duration': 196.07908599243305,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['661602ee-c2c1-40f6-8c08-7bb6bf0b0b04',
#    'be885a27-5021-46d8-afd5-24907f15017d'],
#   'coords': (934629.507202, -258852.163563, 2552.06)},
#  {'id_node': 'dbaa3ebc-c77a-472f-9b5a-e5c05abea177',
#   'features': [{'id_connection': '4b56e3d8b3f084bcac1f7739146685305eec5b5b',
#     'name': 'Campagnols',
#     'difficulty': 'novice',
#     'duration': 35.46639580298881,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['06570f28-391c-4440-b62d-9fea23ba4216'],
#   'coords': (933582.5554414167, -258455.08627233337, 2271.387222222222)},
#  {'id_node': '351d124c-d474-44f5-811e-9e7a26b92460',
#   'features': [{'id_connection': 'd0c77a8474ec1d5685d588953fd2bc4b9de41ff8',
#     'name': 'Bleuets',
#     'difficulty': 'easy',
#     'duration': 66.1793311302033,
#     'connection_type': 'run'},
#    {'id_connection': '0f97ef46ec9cef8503ba11c87a727bea6be0d4fe',
#     'name': 'Dalles',
#     'difficulty': 'easy',
#     'duration': 146.39134557386635,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['1f278abd-3a58-4c13-bb36-f86ddd98a9d0',
#    'f890c3d1-1d59-4870-badb-eb72bc735d38'],
#   'coords': (934026.795705, -258931.301383, 2398.86)},
#  {'id_node': '5baadc6a-d3cb-458f-b880-1fa0ff202570',
#   'features': [{'id_connection': 'f56bbf366faa47c2109862db0d76a833c120df56',
#     'name': 'Vires',
#     'difficulty': 'intermediate',
#     'duration': 111.56668292690829,
#     'connection_type': 'run'},
#    {'id_connection': '327610f1acb523e9c5c26e69b849fb180f9939b7',
#     'name': 'Lac Blanc',
#     'difficulty': 'intermediate',
#     'duration': 210.00966162612798,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['ff862a54-a116-4cfb-bf9f-abbe0653ec2d',
#    '41848869-18d3-45b3-a6bb-85ffdc9a7a0d'],
#   'coords': (936258.463208, -258353.34121500002, 2835.12)},
#  {'id_node': 'b4a639ef-03c8-447a-8850-b3dfc9dafff4',
#   'features': [{'id_connection': 'dcef2417a206957a9e45feb53e833fab7f0c3423',
#     'name': 'Flocon',
#     'difficulty': 'novice',
#     'duration': 92.7550781124725,
#     'connection_type': 'run'},
#    {'id_connection': 'cf0cd1dbb3ab10e500d30c5c51fd628db7744d28',
#     'name': 'Combe de Thorens',
#     'difficulty': 'novice',
#     'duration': 285.6291194771849,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['f890c3d1-1d59-4870-badb-eb72bc735d38',
#    'e590e294-b48f-46e1-a9fa-94923c44ae4f'],
#   'coords': (933772.55961, -259117.980971, 2334.6)},
#  {'id_node': '9fcd3e1d-75a0-45fa-b8b5-581aa61dd858',
#   'features': [{'id_connection': 'e3c50e2270dc473d7588fef9fd67a0fd0e4dacb1',
#     'name': None,
#     'difficulty': 'freeride',
#     'duration': 68.96667743212171,
#     'connection_type': 'run'},
#    {'id_connection': '0602c22d0ee93ab4320c45ce4d9d3cea5b49f867',
#     'name': 'Béranger',
#     'difficulty': 'intermediate',
#     'duration': 330.9113378839116,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['5f8cd608-41a6-4614-9c2c-d18b3c0452bf',
#    '41848869-18d3-45b3-a6bb-85ffdc9a7a0d'],
#   'coords': (935553.406693, -258599.127667, 2656.97)},
#  {'id_node': 'abe0f721-801e-4cb6-a4b5-38f811187cdb',
#   'features': [{'id_connection': '5853179092256f0bdd9c5d5e9e912c43c7bd8218',
#     'name': None,
#     'difficulty': 'intermediate',
#     'duration': 21.1954633193594,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['bf2ded24-49a7-4438-87ed-9be0dc4cc1bb'],
#   'coords': (933843.582544, -259758.9751, 2403.34)},
#  {'id_node': '5b85f5f9-fc11-46e6-a5e7-4546ee7f05d3',
#   'features': [{'id_connection': '536d5de649734f79af1c8c27480d9f3daa5ca7cb',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 49.2660226319262,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['37dc8140-c7a2-4958-accf-d4aca576381b'],
#   'coords': (934095.6481381111, -259672.3034005556, 2410.9166666666665)},
#  {'id_node': '99c702a9-962d-4143-9d45-63c84d67446d',
#   'features': [{'id_connection': 'a1ce835ad3b70417de259f36d9e752aee5a3c45f',
#     'name': 'Adrien Théaux',
#     'difficulty': 'intermediate',
#     'duration': 223.57982463790765,
#     'connection_type': 'run'},
#    {'id_connection': '0602c22d0ee93ab4320c45ce4d9d3cea5b49f867',
#     'name': 'Béranger',
#     'difficulty': 'intermediate',
#     'duration': 330.9113378839116,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['95bc412f-4707-461b-84b1-ad75ab4b75fa',
#    '1f278abd-3a58-4c13-bb36-f86ddd98a9d0'],
#   'coords': (934409.7234147501, -258453.09299, 2416.705)},
#  {'id_node': 'db13c886-14ed-4e21-bd3b-c07afb0e3898',
#   'features': [{'id_connection': 'f6e55142158a27a5852ca075e70abc274dcee92f',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 12.422133379947054,
#     'connection_type': 'run'},
#    {'id_connection': '3055b1da6a1afa35b1b04040acebc7d238390486',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 7.992372199704732,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['5e103bba-f403-496f-8290-e313c4b62011',
#    'ff8dd7ce-0731-4053-8f19-594f01a31165'],
#   'coords': (934031.5606505834, -258445.41224458333, 2330.2416666666663)},
#  {'id_node': 'be885a27-5021-46d8-afd5-24907f15017d',
#   'features': [{'id_connection': '97d7066b4dd04376cb265f523855b17fbcee2142',
#     'name': 'Cascades',
#     'difficulty': 'advanced',
#     'duration': 63.928551229585956,
#     'connection_type': 'run'},
#    {'id_connection': 'f8b504cf58e9643370192bc078ff603cb80efbc9',
#     'name': '2 Combes',
#     'difficulty': 'novice',
#     'duration': 196.07908599243305,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['1f278abd-3a58-4c13-bb36-f86ddd98a9d0',
#    '661602ee-c2c1-40f6-8c08-7bb6bf0b0b04'],
#   'coords': (934559.5161880001, -258745.224872, 2526.77)},
#  {'id_node': 'bcdfd303-a160-46e2-a449-5aabba075352',
#   'features': [{'id_connection': 'b861b13571e176a237379b295bf405551b9ca7c0',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 38.09796171006335,
#     'connection_type': 'run'},
#    {'id_connection': '1841068a3096e585f54dceb9acd62f5c769df22a',
#     'name': 'Altiport',
#     'difficulty': 'easy',
#     'duration': 88.00809327607024,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['d4f4dd04-f8f5-4402-a624-fd03b56b8e2a',
#    '560bfa85-bced-4a2a-99cf-2230497602f6'],
#   'coords': (933080.795549, -259946.0168415, 2494.465)},
#  {'id_node': 'f890c3d1-1d59-4870-badb-eb72bc735d38',
#   'features': [{'id_connection': 'b84dbc99743a546fc368f65df6dd448466282cb0',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 19.498518631913416,
#     'connection_type': 'run'},
#    {'id_connection': 'dcef2417a206957a9e45feb53e833fab7f0c3423',
#     'name': 'Flocon',
#     'difficulty': 'novice',
#     'duration': 92.7550781124725,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['e590e294-b48f-46e1-a9fa-94923c44ae4f',
#    '1e82a343-1df8-411e-a815-293e1c3c73e2'],
#   'coords': (933805.9719196666, -258839.55705499998, 2331.5166666666664)},
#  {'id_node': '9f5936f3-3d62-4a56-a6c5-a7fbe8c6092f',
#   'features': [{'id_connection': '21a74c32a8404fe334cfd28e5ce19225e03eacfe',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 16.725672036160855,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['1e82a343-1df8-411e-a815-293e1c3c73e2'],
#   'coords': (933940.243546, -258439.463415, 2322.93)},
#  {'id_node': '52685ee0-d917-4656-97aa-24fd14954edb',
#   'features': [{'id_connection': '142c4ec8f0f42e910349ce44c0ac2f9291aae14c',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 16.514211436596238,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['94a9cf65-abb1-445e-a29f-64e1aace3ae9'],
#   'coords': (933704.914795, -258100.789334, 2317.4)},
#  {'id_node': '542ee469-28aa-4b02-b8cf-86200a4f0d80',
#   'features': [{'id_connection': '66e1131dc689da599799d68d83deb89930319192',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 25.848466177137926,
#     'connection_type': 'run'},
#    {'id_connection': '0a08b41aa177470635ed024b47f553f880ccd33c',
#     'name': 'Plein Sud',
#     'difficulty': 'easy',
#     'duration': 102.14281338460869,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['0c4f8ac1-26ad-46a6-b949-3d43573ca69d',
#    '8fb47ff5-950b-4f5c-a3b8-f9f561bb359f'],
#   'coords': (933124.224787, -258248.129494, 2243.5)},
#  {'id_node': '9f580e03-49cf-4eb2-961e-d46774655726',
#   'features': [{'id_connection': '4a0dc6758c5f84644e17a57c9d14d88f3acccf1a',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 24.32756811608675,
#     'connection_type': 'run'},
#    {'id_connection': '33d92b2cbbd0e98974f3fafa771d1f3aab5a1cce',
#     'name': 'Traversée Deux Lacs',
#     'difficulty': 'novice',
#     'duration': 106.75676203919343,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['bf2ded24-49a7-4438-87ed-9be0dc4cc1bb',
#    '5d30d5c1-7575-4ebb-b91f-0a65816706c9'],
#   'coords': (933643.697269, -259620.823411, 2403.75)},
#  {'id_node': '37dc8140-c7a2-4958-accf-d4aca576381b',
#   'features': [{'id_connection': 'd34ad93c2401a07d2a083778c9ca62db64618408',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 60.4707220335743,
#     'connection_type': 'run'},
#    {'id_connection': '536d5de649734f79af1c8c27480d9f3daa5ca7cb',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 49.2660226319262,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['db69abec-ea3e-47fe-a005-82abcb381d4b',
#    'f7d2d19b-7e30-42cd-86cc-1d4a7f81f67d'],
#   'coords': (933921.003274, -259537.188556, 2378.4)},
#  {'id_node': '475f6d1f-5b17-41be-9703-7a76180db635',
#   'features': [{'id_connection': 'a1ce835ad3b70417de259f36d9e752aee5a3c45f',
#     'name': 'Adrien Théaux',
#     'difficulty': 'intermediate',
#     'duration': 223.57982463790765,
#     'connection_type': 'run'},
#    {'id_connection': 'a0bb99c174db2bf009db1d1dbf8b918fe0a16b4a',
#     'name': 'Croissant',
#     'difficulty': 'intermediate',
#     'duration': 204.52849667950392,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['abcd4a74-3f9a-4159-a210-87eec8ca3317',
#    'b5599277-56d9-41f0-8e15-0b0cac6775fb'],
#   'coords': (935414.71987, -258133.942325, 2747.61)},
#  {'id_node': 'df07ef11-008e-423f-b06b-2284d467d8a4',
#   'features': [{'id_connection': '0d6210a62b5dd08a714377c58b0cff432d6e5091',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 8.847167085371142,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['5b85f5f9-fc11-46e6-a5e7-4546ee7f05d3'],
#   'coords': (934143.988499, -259708.498273, 2416.6)},
#  {'id_node': 'ff862a54-a116-4cfb-bf9f-abbe0653ec2d',
#   'features': [{'id_connection': 'bf75c38fd2d0d44d9990ff17546888610fa6bca2',
#     'name': 'Boulevard Lauzes',
#     'difficulty': 'intermediate',
#     'duration': 220.09629491958728,
#     'connection_type': 'run'},
#    {'id_connection': 'a0bb99c174db2bf009db1d1dbf8b918fe0a16b4a',
#     'name': 'Croissant',
#     'difficulty': 'intermediate',
#     'duration': 204.52849667950392,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['41848869-18d3-45b3-a6bb-85ffdc9a7a0d',
#    'ce2fbb59-e17a-40a1-960e-189ebb11c790'],
#   'coords': (935675.0629950626, -258162.1570766875, 2760.2462499999997)},
#  {'id_node': 'ce2fbb59-e17a-40a1-960e-189ebb11c790',
#   'features': [{'id_connection': 'a0bb99c174db2bf009db1d1dbf8b918fe0a16b4a',
#     'name': 'Croissant',
#     'difficulty': 'intermediate',
#     'duration': 204.52849667950392,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['475f6d1f-5b17-41be-9703-7a76180db635'],
#   'coords': (935593.9676143333, -258173.67523599998, 2750.536666666667)},
#  {'id_node': 'ad10d131-f89f-4d01-a2ff-70148e16a831',
#   'features': [{'id_connection': '2472dd4d67997d735113bd4d37f4a3cb2d4abd4a',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 9.395739316950435,
#     'connection_type': 'run'},
#    {'id_connection': 'e175be38c168d85780154d8b66cc1ce0fcd30c65',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 61.421354970124426,
#     'connection_type': 'run'},
#    {'id_connection': 'f5bd0831bd8b7a3724442729195fbfe2aa291213',
#     'name': 'Lac Blanc',
#     'difficulty': 'lift',
#     'duration': 485.00389513358977,
#     'connection_type': 'lift'}],
#   'id_connected_nodes': ['715356a3-6eae-44cd-ae7d-7a67f62896fa',
#    '4ac1da52-f595-48d0-8e10-18f5366765a9',
#    'ce2fbb59-e17a-40a1-960e-189ebb11c790'],
#   'coords': (933707.1708653334, -258513.25843516667, 2287.4449999999997)},
#  {'id_node': '69514b9e-5bd6-44c4-b9bc-ce6437c8ae8f',
#   'features': [{'id_connection': '5bab5ab7d4c42084fcd2d4258a034dd06642effa',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 25.604400354122085,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['d7b639e2-55c8-4399-a95f-1ddc05fa7e94'],
#   'coords': (933881.488662, -258264.755419, 2328.15)},
#  {'id_node': 'fefc089a-92eb-4d85-9bd3-36db9574c85c',
#   'features': [{'id_connection': '45080627d3faec5a150fbccff7fcd193a28e1942',
#     'name': 'Corniche',
#     'difficulty': 'easy',
#     'duration': 211.68946045133774,
#     'connection_type': 'run'},
#    {'id_connection': '1744840abdd56aca2391499c8df2c252f1ca31ae',
#     'name': 'Plein Sud',
#     'difficulty': 'easy',
#     'duration': 257.6864939105756,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['b5599277-56d9-41f0-8e15-0b0cac6775fb',
#    'a56367d0-e355-447a-bcab-a05254caaf7e'],
#   'coords': (934012.8572731666, -257422.66897066668, 2530.885)},
#  {'id_node': '7e92f9a8-0b52-4e17-bef2-e690b9f3f5a5',
#   'features': [{'id_connection': '5a8ded9d52cf7e343655470de174dbd059abfbed',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 11.774884212211896,
#     'connection_type': 'run'},
#    {'id_connection': '45080627d3faec5a150fbccff7fcd193a28e1942',
#     'name': 'Corniche',
#     'difficulty': 'easy',
#     'duration': 211.68946045133774,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['cc8a6e97-d8c7-492c-9da2-ced8a756bead',
#    'db13c886-14ed-4e21-bd3b-c07afb0e3898'],
#   'coords': (934134.7918245001, -258411.9306475, 2358.19)},
#  {'id_node': 'd7b639e2-55c8-4399-a95f-1ddc05fa7e94',
#   'features': [{'id_connection': '83cc46aeabdf41aa2a51f64f6861937ddf8dc24e',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 7.005691197250604,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['4e86065b-7cba-4b5f-9af2-1e4c5d5b7973'],
#   'coords': (933848.4719110001, -258429.87299375, 2309.2875)},
#  {'id_node': '5aa4f52b-2ceb-4e31-a760-c72e429bd0e6',
#   'features': [{'id_connection': '831a8bf3e0a4d6a5d16191b0ef22420498d04526',
#     'name': 'Voie de la Boucle',
#     'difficulty': 'easy',
#     'duration': 24.81241859944635,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['2b362fa7-4dea-43a6-bca3-7dd28d3776c1'],
#   'coords': (933416.0312431667, -258272.08504316665, 2276.4266666666667)},
#  {'id_node': '360cfb35-c079-43d7-a19c-b77dc40963fc',
#   'features': [{'id_connection': '76e95c65755f7c37d89150f2d20ab009478a16d7',
#     'name': None,
#     'difficulty': 'intermediate',
#     'duration': 25.867271719288485,
#     'connection_type': 'run'},
#    {'id_connection': '7114a9d26c0ded42d29bbca523a5a57d42bae4c2',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 47.962257870088614,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['368452a9-142f-4f87-ba66-d4dc74c5f50d',
#    'f8eef11d-4080-4907-bc4b-d3480f311523'],
#   'coords': (933558.61667, -257760.281022, 2401.64)},
#  {'id_node': '3a9b4119-873d-496b-83de-6ed763f33cba',
#   'features': [{'id_connection': 'ff38339273678c64e311ae3304b6bd17f3123fa4',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 8.229568090385602,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['6742705a-4cc3-4c56-8085-331af2c08fb3'],
#   'coords': (933961.908052, -258092.950499, 2356.85)},
#  {'id_node': '46250c08-2014-4c7e-bed9-fed03921dd16',
#   'features': [{'id_connection': '8441b1b0d09f841554c9b4f9398843adc20cf462',
#     'name': None,
#     'difficulty': 'intermediate',
#     'duration': 72.06412183515629,
#     'connection_type': 'run'},
#    {'id_connection': '20432332cc7a714c671e4105235d1ce2a757f8cc',
#     'name': 'Tête Ronde',
#     'difficulty': 'easy',
#     'duration': 371.564196293215,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['e45f176c-77b0-4e0f-bbf1-baddc3e3d366',
#    '126bf4e2-7a04-4fed-a648-0ffeb2f92683'],
#   'coords': (936176.986146, -258987.783293, 2913.47)},
#  {'id_node': '381354cb-9a0e-4109-a09f-bbba49bcd935',
#   'features': [{'id_connection': '3d864a343ab1fba9b33f5600944452c530099f7d',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 15.2361444216169,
#     'connection_type': 'run'},
#    {'id_connection': 'd172da53602b44edf7714b27e92fcf087ddbf398',
#     'name': 'Voie de la Boucle',
#     'difficulty': 'easy',
#     'duration': 36.70842631281597,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['516ca8ce-7295-4390-be75-2c2087eebdf5',
#    '5aa4f52b-2ceb-4e31-a760-c72e429bd0e6'],
#   'coords': (933294.6852276666, -258181.62873533336, 2278.87)},
#  {'id_node': '0cba62a6-51a6-4e40-8912-e7badb57650d',
#   'features': [{'id_connection': 'c68102822fb02b9730b2b90f9fe6204f15e36d2b',
#     'name': 'Skicross Jean-Fred Chapuis',
#     'difficulty': 'intermediate',
#     'duration': 101.2881245044437,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['ee0579be-a062-43e9-a7f8-dd94d066d75f'],
#   'coords': (933195.190505, -258967.84221, 2387.78)},
#  {'id_node': '9954b434-1c49-409a-ae78-044c18cd3e7f',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (934547.727766, -260980.875976, 2784.66)},
#  {'id_node': 'ad8c91ba-429a-42b3-8bfc-eb41f53ac29c',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (935711.793864, -260813.594985, 2803.24)},
#  {'id_node': '7f0fbd5c-2197-488a-b9e7-88ec53834595',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (933931.773522, -253343.332421, 2117.21)},
#  {'id_node': 'd6c9322e-10dc-47a7-bc1f-a22e97586362',
#   'features': [{'id_connection': 'de62cf329428aa5ea0c488305855c280792d6119',
#     'name': 'Hermine',
#     'difficulty': 'easy',
#     'duration': 223.95997630712594,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['62da9c9f-75f4-402b-ae40-1f5c4e1d14f1'],
#   'coords': (933024.758989, -259560.195727, 2440.74)},
#  {'id_node': '790f6cca-5f4b-4695-b009-80d90492bda5',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (932676.087534, -260076.305535, 2448.69)},
#  {'id_node': '92e60670-a84a-4768-896b-3a5fe70165f1',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (932674.175266, -257565.240127, 2351.72)},
#  {'id_node': '4b57385b-ce7c-4bac-bfdb-21a520c839b1',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (933311.373689, -256350.853206, 2737.04)},
#  {'id_node': '661602ee-c2c1-40f6-8c08-7bb6bf0b0b04',
#   'features': [{'id_connection': 'f8b504cf58e9643370192bc078ff603cb80efbc9',
#     'name': '2 Combes',
#     'difficulty': 'novice',
#     'duration': 196.07908599243305,
#     'connection_type': 'run'},
#    {'id_connection': '0f97ef46ec9cef8503ba11c87a727bea6be0d4fe',
#     'name': 'Dalles',
#     'difficulty': 'easy',
#     'duration': 146.39134557386635,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['5b85f5f9-fc11-46e6-a5e7-4546ee7f05d3',
#    '351d124c-d474-44f5-811e-9e7a26b92460'],
#   'coords': (934367.41485, -259018.14101366667, 2493.7166666666667)},
#  {'id_node': '0f519bca-1d16-49ea-86ee-8a157f0482dc',
#   'features': [{'id_connection': 'dca4a5b46f4523559d661bfa1e6e9572a9f41ce0',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 60.020400448849344,
#     'connection_type': 'run'},
#    {'id_connection': 'df3671475b35952edae0eb55fbabbb8a2306a1c1',
#     'name': '3 Vallées',
#     'difficulty': 'lift',
#     'duration': 214.0,
#     'connection_type': 'lift'},
#    {'id_connection': 'af3bce64bc75415b0490f9c90ac08299e5ced573',
#     'name': 'Funitel 3 Vallées',
#     'difficulty': 'lift',
#     'duration': 112.0,
#     'connection_type': 'lift'},
#    {'id_connection': 'bfb2cf764aa3158a21be101792af7aee4b4adf20',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 23.95439016754696,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['843f6728-85b4-466c-ba8e-10062091562f',
#    '50c5ca6a-16b4-4314-b30a-bb8f6136f595',
#    'f075f26a-5066-49b0-9f30-fb85c42e17af',
#    '9c173425-99b8-404d-93c0-9e990b2c84fb'],
#   'coords': (933935.1410815, -257301.65151766664, 2536.37)},
#  {'id_node': 'b1bd1257-18f7-4978-8f91-96d9763ed061',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (933118.820674, -257960.806429, 2303.67)},
#  {'id_node': 'f8eef11d-4080-4907-bc4b-d3480f311523',
#   'features': [{'id_connection': '1744840abdd56aca2391499c8df2c252f1ca31ae',
#     'name': 'Plein Sud',
#     'difficulty': 'easy',
#     'duration': 257.6864939105756,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['862c50b2-b5f2-4b0d-8e6e-e13b7152ae3b'],
#   'coords': (933678.868339, -257865.761246, 2366.35)},
#  {'id_node': '57f7c706-113e-48e6-b917-f675f57f9167',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (932105.759977, -256694.964771, 2339.53)},
#  {'id_node': 'f8a13995-b740-4898-aad7-9bc0d034727b',
#   'features': [{'id_connection': '0602c22d0ee93ab4320c45ce4d9d3cea5b49f867',
#     'name': 'Béranger',
#     'difficulty': 'intermediate',
#     'duration': 330.9113378839116,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['99c702a9-962d-4143-9d45-63c84d67446d'],
#   'coords': (934786.2427151666, -258555.8816031667, 2535.2066666666665)},
#  {'id_node': '0cd69478-a986-41bd-a73c-ae9d4ef20288',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (932260.979049, -258848.25408, 2128.89)},
#  {'id_node': '7388d166-3fde-48b7-a26a-57d3dfbc1ec0',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (932863.99603, -255843.520931, 2711.5)},
#  {'id_node': '0cfe13fc-b16b-40be-8e15-4928ad8275e8',
#   'features': [{'id_connection': '12dbf578b4ff6409e4a345da36cd018281998937',
#     'name': 'Pluviomètre',
#     'difficulty': 'easy',
#     'duration': 316.3754759896956,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['92e60670-a84a-4768-896b-3a5fe70165f1'],
#   'coords': (933721.775087, -256732.785603, 2706.17)},
#  {'id_node': '9f200f82-f2f9-4115-8e87-a9d95ce8a058',
#   'features': [{'id_connection': 'e295e1fee4fad60521bfad7e5c0efb50b3571787',
#     'name': '4 Vents',
#     'difficulty': 'intermediate',
#     'duration': 188.18659371986328,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['57f7c706-113e-48e6-b917-f675f57f9167'],
#   'coords': (933088.561242, -256285.214302, 2686.56)},
#  {'id_node': 'a56367d0-e355-447a-bcab-a05254caaf7e',
#   'features': [{'id_connection': '1744840abdd56aca2391499c8df2c252f1ca31ae',
#     'name': 'Plein Sud',
#     'difficulty': 'easy',
#     'duration': 257.6864939105756,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['83faac15-8f26-468e-87a6-c14ba6b9181d'],
#   'coords': (933737.949039, -257565.471518, 2452.48)},
#  {'id_node': '61f8c793-d30e-4ac7-8e0f-39733e9919cf',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (932886.335883, -258477.169535, 2203.95)},
#  {'id_node': '407235cd-cbf5-4e88-b51e-385ace63e1d8',
#   'features': [{'id_connection': '0a08b41aa177470635ed024b47f553f880ccd33c',
#     'name': 'Plein Sud',
#     'difficulty': 'easy',
#     'duration': 102.14281338460869,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['516ca8ce-7295-4390-be75-2c2087eebdf5'],
#   'coords': (933235.39776, -258134.394904, 2276.14)},
#  {'id_node': '67f5fed5-ecfa-486d-86c5-dbeea94e20b4',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (933903.08159, -258122.216031, 2338.0)},
#  {'id_node': '4e446617-97e3-48f6-87fb-9686ebd39360',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (932805.984181, -258459.81774, 2194.94)},
#  {'id_node': 'aa33da10-5b4f-48cc-a22f-be643298f9ce',
#   'features': [{'id_connection': '1744840abdd56aca2391499c8df2c252f1ca31ae',
#     'name': 'Plein Sud',
#     'difficulty': 'easy',
#     'duration': 257.6864939105756,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['862c50b2-b5f2-4b0d-8e6e-e13b7152ae3b'],
#   'coords': (933773.4049315, -257930.731525, 2341.66)},
#  {'id_node': '95bc412f-4707-461b-84b1-ad75ab4b75fa',
#   'features': [{'id_connection': 'a1ce835ad3b70417de259f36d9e752aee5a3c45f',
#     'name': 'Adrien Théaux',
#     'difficulty': 'intermediate',
#     'duration': 223.57982463790765,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['db13c886-14ed-4e21-bd3b-c07afb0e3898'],
#   'coords': (934189.701926, -258431.81763, 2371.76)},
#  {'id_node': '843f6728-85b4-466c-ba8e-10062091562f',
#   'features': [{'id_connection': 'dca4a5b46f4523559d661bfa1e6e9572a9f41ce0',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 60.020400448849344,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['a56367d0-e355-447a-bcab-a05254caaf7e'],
#   'coords': (933870.145124, -257327.943535, 2526.49)},
#  {'id_node': '62da9c9f-75f4-402b-ae40-1f5c4e1d14f1',
#   'features': [{'id_connection': 'de62cf329428aa5ea0c488305855c280792d6119',
#     'name': 'Hermine',
#     'difficulty': 'easy',
#     'duration': 223.95997630712594,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['0cd69478-a986-41bd-a73c-ae9d4ef20288'],
#   'coords': (932598.148787, -259288.7524595, 2252.71)},
#  {'id_node': '1e82a343-1df8-411e-a815-293e1c3c73e2',
#   'features': [{'id_connection': 'b2cbfe63c2b8626311d669bc02a94b0bee680e1d',
#     'name': 'Roc',
#     'difficulty': 'novice',
#     'duration': 81.40222165057398,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['715356a3-6eae-44cd-ae7d-7a67f62896fa'],
#   'coords': (933879.9136573332, -258535.81007600002, 2312.816666666667)},
#  {'id_node': '5f8cd608-41a6-4614-9c2c-d18b3c0452bf',
#   'features': [{'id_connection': 'bf75c38fd2d0d44d9990ff17546888610fa6bca2',
#     'name': 'Boulevard Lauzes',
#     'difficulty': 'intermediate',
#     'duration': 220.09629491958728,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['847a48e6-ab13-4459-91bf-72f2ce5ba1fc'],
#   'coords': (935106.757005, -258737.24597, 2597.8900000000003)},
#  {'id_node': 'bf2ded24-49a7-4438-87ed-9be0dc4cc1bb',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (933805.9600905, -259624.2803345, 2384.94)},
#  {'id_node': 'f7d2d19b-7e30-42cd-86cc-1d4a7f81f67d',
#   'features': [{'id_connection': 'cf0cd1dbb3ab10e500d30c5c51fd628db7744d28',
#     'name': 'Combe de Thorens',
#     'difficulty': 'novice',
#     'duration': 285.6291194771849,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['d4943d79-0f93-41c8-a590-2f639c0c24f7'],
#   'coords': (933843.144794, -259441.615592, 2357.52)},
#  {'id_node': 'd4f4dd04-f8f5-4402-a624-fd03b56b8e2a',
#   'features': [{'id_connection': '1841068a3096e585f54dceb9acd62f5c769df22a',
#     'name': 'Altiport',
#     'difficulty': 'easy',
#     'duration': 88.00809327607024,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['790f6cca-5f4b-4695-b009-80d90492bda5'],
#   'coords': (932998.056895, -260111.328233, 2475.25)},
#  {'id_node': 'e590e294-b48f-46e1-a9fa-94923c44ae4f',
#   'features': [{'id_connection': 'cf0cd1dbb3ab10e500d30c5c51fd628db7744d28',
#     'name': 'Combe de Thorens',
#     'difficulty': 'novice',
#     'duration': 285.6291194771849,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['715356a3-6eae-44cd-ae7d-7a67f62896fa'],
#   'coords': (933688.256614, -258765.950134, 2308.61)},
#  {'id_node': '41848869-18d3-45b3-a6bb-85ffdc9a7a0d',
#   'features': [{'id_connection': '0602c22d0ee93ab4320c45ce4d9d3cea5b49f867',
#     'name': 'Béranger',
#     'difficulty': 'intermediate',
#     'duration': 330.9113378839116,
#     'connection_type': 'run'},
#    {'id_connection': 'bf75c38fd2d0d44d9990ff17546888610fa6bca2',
#     'name': 'Boulevard Lauzes',
#     'difficulty': 'intermediate',
#     'duration': 220.09629491958728,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['f8a13995-b740-4898-aad7-9bc0d034727b',
#    '5f8cd608-41a6-4614-9c2c-d18b3c0452bf'],
#   'coords': (935434.9951926667, -258554.876439, 2627.5266666666666)},
#  {'id_node': '4ac1da52-f595-48d0-8e10-18f5366765a9',
#   'features': [{'id_connection': 'e175be38c168d85780154d8b66cc1ce0fcd30c65',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 61.421354970124426,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['dbaa3ebc-c77a-472f-9b5a-e5c05abea177'],
#   'coords': (933656.6006368333, -258495.86189583334, 2278.908333333333)},
#  {'id_node': '6274005e-08b6-4e6a-9ee4-ae0527f822c2',
#   'features': [{'id_connection': '142c4ec8f0f42e910349ce44c0ac2f9291aae14c',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 16.514211436596238,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['94a9cf65-abb1-445e-a29f-64e1aace3ae9'],
#   'coords': (933709.913833, -258216.228596, 2311.12)},
#  {'id_node': 'db69abec-ea3e-47fe-a005-82abcb381d4b',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (933824.662126, -259135.072903, 2341.53)},
#  {'id_node': 'b5599277-56d9-41f0-8e15-0b0cac6775fb',
#   'features': [{'id_connection': '45080627d3faec5a150fbccff7fcd193a28e1942',
#     'name': 'Corniche',
#     'difficulty': 'easy',
#     'duration': 211.68946045133774,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['7e92f9a8-0b52-4e17-bef2-e690b9f3f5a5'],
#   'coords': (934334.1824055, -258228.4285995, 2456.61)},
#  {'id_node': 'cc8a6e97-d8c7-492c-9da2-ced8a756bead',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (934065.527989, -258373.425313, 2345.36)},
#  {'id_node': '4e86065b-7cba-4b5f-9af2-1e4c5d5b7973',
#   'features': [{'id_connection': 'e175be38c168d85780154d8b66cc1ce0fcd30c65',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 61.421354970124426,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['ad10d131-f89f-4d01-a2ff-70148e16a831'],
#   'coords': (933844.0957885, -258457.287167, 2306.855)},
#  {'id_node': 'ff8dd7ce-0731-4053-8f19-594f01a31165',
#   'features': [{'id_connection': '3055b1da6a1afa35b1b04040acebc7d238390486',
#     'name': None,
#     'difficulty': 'novice',
#     'duration': 7.992372199704732,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['db13c886-14ed-4e21-bd3b-c07afb0e3898'],
#   'coords': (934007.755214, -258398.38064, 2332.12)},
#  {'id_node': '368452a9-142f-4f87-ba66-d4dc74c5f50d',
#   'features': [],
#   'id_connected_nodes': [],
#   'coords': (933463.462386, -257892.502693, 2359.74)},
#  {'id_node': '6742705a-4cc3-4c56-8085-331af2c08fb3',
#   'features': [{'id_connection': '99c505c80ee7d459c0816bb0356acbd589f2ee11',
#     'name': None,
#     'difficulty': 'easy',
#     'duration': 24.061522807757626,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['67f5fed5-ecfa-486d-86c5-dbeea94e20b4'],
#   'coords': (933910.6143155, -258055.783961, 2348.2)},
#  {'id_node': 'e45f176c-77b0-4e0f-bbf1-baddc3e3d366',
#   'features': [{'id_connection': '0602c22d0ee93ab4320c45ce4d9d3cea5b49f867',
#     'name': 'Béranger',
#     'difficulty': 'intermediate',
#     'duration': 330.9113378839116,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['9fcd3e1d-75a0-45fa-b8b5-581aa61dd858'],
#   'coords': (935793.174746, -258791.384904, 2781.9)},
#  {'id_node': '516ca8ce-7295-4390-be75-2c2087eebdf5',
#   'features': [{'id_connection': '0a08b41aa177470635ed024b47f553f880ccd33c',
#     'name': 'Plein Sud',
#     'difficulty': 'easy',
#     'duration': 102.14281338460869,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['542ee469-28aa-4b02-b8cf-86200a4f0d80'],
#   'coords': (933206.345456, -258185.8792015, 2264.11)},
#  {'id_node': 'ee0579be-a062-43e9-a7f8-dd94d066d75f',
#   'features': [{'id_connection': 'aef83b4b86635dfc8fd2648f1fc0118258b3468c',
#     'name': 'Chalets',
#     'difficulty': 'easy',
#     'duration': 192.49163853097676,
#     'connection_type': 'run'}],
#   'id_connected_nodes': ['8fb47ff5-950b-4f5c-a3b8-f9f561bb359f'],
#   'coords': (933060.6105901666, -258405.00072466666, 2221.745)}]

# %%
points[points.id == run_id].geometry
# Out:
# 1342    POINT Z (933124.225 -258248.129 2243.500)
# 1343    POINT Z (933115.900 -258282.544 2236.750)
# 1344    POINT Z (933116.959 -258296.869 2234.750)
# 1345    POINT Z (933123.929 -258312.680 2234.440)
# 1346    POINT Z (933136.112 -258329.726 2235.120)
# 1347    POINT Z (933152.939 -258343.787 2235.680)
# 1348    POINT Z (933189.201 -258376.250 2238.440)
# 1349    POINT Z (933200.082 -258381.763 2239.360)
# 1350    POINT Z (933202.259 -258384.486 2239.360)
# 1351    POINT Z (933201.974 -258387.683 2239.360)
# 1352    POINT Z (933200.488 -258390.790 2239.360)
# Name: geometry, dtype: geometry

# %%
check_shape(run_points, start_point, end_point)
# Out:
# ['U', 'U', 'U', 'U', 'U', 'U']

# %%
test_data[(test_data.start.apply(lambda x: x.coords[0][2]) < test_data.end.apply(lambda x: x.coords[0][2])) & (test_data.connection_type!="lift")]
# Out:
#       Index                                        id  name  \
# 40    47847  87c433c36090d045443b7b951cffd556462c4e4b  None
# 46    55275  32b2cdf175ee03453a7fba54ba25ac361b98c04b  None
# 69    58653  1d6bc590520355bd206518161d5634365d2086a5  None
# 70    58661  77f7d3631a24e6f47862cff157703925b04495d0  None
# 85    81339  08b0c4421bb78ab417b27a179e7bcccf2fa565aa  None
# 92    93279  c1d6b9eae987a999716148edd967e21951bc93f6  None
# 94    93281  cf1e0863d54b7d65304393a326d072803e13302b  None
# 100  100702  007d28074efd19753d3088959fba87b5c68e13ca  None
# 110  124209  7e756fede58f25ffd9f3312a2b231a67dd1bfdec  None
#
#            resort_name connection_type    difficulty   duration   distance  \
# 40   Les Trois Vallées             run          easy   7.090978  49.636847
# 46   Les Trois Vallées             run          easy   1.586005  11.102035
# 69   Les Trois Vallées             run        novice   6.484735  45.393145
# 70   Les Trois Vallées             run        novice  10.499161  73.494125
# 85   Les Trois Vallées             run        novice   5.518438  38.629065
# 92   Les Trois Vallées             run  intermediate  14.091935  98.643547
# 94   Les Trois Vallées             run        novice   8.910438  62.373067
# 100  Les Trois Vallées             run          easy   2.443311  17.103179
# 110  Les Trois Vallées             run          None   2.331599  16.321195
#
#                                               geometry  \
# 40   LINESTRING Z (933991.475 -257319.912 2540.520,...
# 46   LINESTRING Z (936238.232 -258682.816 2919.050,...
# 69   LINESTRING Z (933089.704 -259464.644 2446.820,...
# 70   LINESTRING Z (933336.931 -258401.808 2250.040,...
# 85   LINESTRING Z (933814.654 -259374.213 2351.270,...
# 92   LINESTRING Z (935591.840 -258165.657 2752.870,...
# 94   LINESTRING Z (933649.061 -258559.471 2284.380,...
# 100  LINESTRING Z (933650.926 -258374.234 2278.550,...
# 110  LINESTRING Z (933823.417 -259369.099 2351.270,...
#
#                                          start  \
# 40   POINT Z (933991.475 -257319.912 2540.520)
# 46   POINT Z (936238.232 -258682.816 2919.050)
# 69   POINT Z (933089.704 -259464.644 2446.820)
# 70   POINT Z (933336.931 -258401.808 2250.040)
# 85   POINT Z (933814.654 -259374.213 2351.270)
# 92   POINT Z (935591.840 -258165.657 2752.870)
# 94   POINT Z (933649.061 -258559.471 2284.380)
# 100  POINT Z (933650.926 -258374.234 2278.550)
# 110  POINT Z (933823.417 -259369.099 2351.270)
#
#                                            end
# 40   POINT Z (933974.000 -257289.909 2541.640)
# 46   POINT Z (936247.979 -258688.132 2921.260)
# 69   POINT Z (933115.693 -259458.650 2450.430)
# 70   POINT Z (933319.466 -258460.597 2252.490)
# 85   POINT Z (933835.753 -259378.871 2352.270)
# 92   POINT Z (935672.854 -258169.118 2758.240)
# 94   POINT Z (933702.069 -258534.899 2289.140)
# 100  POINT Z (933661.799 -258387.436 2279.240)
# 110  POINT Z (933836.453 -259373.966 2352.270)

# %%
run_points.reverse()

run_points
# Out:
# [<POINT Z (933200.488 -258390.79 2239.36)>,
#  <POINT Z (933201.974 -258387.683 2239.36)>,
#  <POINT Z (933202.259 -258384.486 2239.36)>,
#  <POINT Z (933200.082 -258381.763 2239.36)>,
#  <POINT Z (933189.201 -258376.25 2238.44)>,
#  <POINT Z (933152.939 -258343.787 2235.68)>,
#  <POINT Z (933136.112 -258329.726 2235.12)>,
#  <POINT Z (933123.929 -258312.68 2234.44)>,
#  <POINT Z (933116.959 -258296.869 2234.75)>,
#  <POINT Z (933115.9 -258282.544 2236.75)>,
#  <POINT Z (933124.225 -258248.129 2243.5)>]

# %%
LineString(run_points)
# Out:
# <LINESTRING Z (933124.225 -258248.129 2243.5, 933115.9 -258282.544 2236.75, ...>

# %%
run_points
# Out:
# [<POINT Z (933124.225 -258248.129 2243.5)>,
#  <POINT Z (933115.9 -258282.544 2236.75)>,
#  <POINT Z (933116.959 -258296.869 2234.75)>,
#  <POINT Z (933123.929 -258312.68 2234.44)>,
#  <POINT Z (933136.112 -258329.726 2235.12)>,
#  <POINT Z (933152.939 -258343.787 2235.68)>,
#  <POINT Z (933189.201 -258376.25 2238.44)>,
#  <POINT Z (933200.082 -258381.763 2239.36)>,
#  <POINT Z (933202.259 -258384.486 2239.36)>,
#  <POINT Z (933201.974 -258387.683 2239.36)>,
#  <POINT Z (933200.488 -258390.79 2239.36)>]

# %%
start_point
# Out:
# (933124.224787, -258248.129494, 2243.5)

# %%
end_point
# Out:
# (933200.487623, -258390.790477, 2239.36)

# %%
check_shape(run_points, start_point, end_point)
# Out:
# ([<POINT Z (933124.225 -258248.129 2243.5)>,
#   <POINT Z (933115.9 -258282.544 2236.75)>,
#   <POINT Z (933116.959 -258296.869 2234.75)>,
#   <POINT Z (933123.929 -258312.68 2234.44)>,
#   <POINT Z (933136.112 -258329.726 2233.44)>,
#   <POINT Z (933152.939 -258343.787 2232.44)>,
#   <POINT Z (933189.201 -258376.25 2231.44)>,
#   <POINT Z (933200.082 -258381.763 2230.44)>,
#   <POINT Z (933202.259 -258384.486 2229.44)>,
#   <POINT Z (933201.974 -258387.683 2228.44)>,
#   <POINT Z (933200.488 -258390.79 2227.44)>],
#  (933124.224787, -258248.129494, 2243.5),
#  <POINT Z (933200.488 -258390.79 2227.44)>,
#  False)

# %%
node_coords = {}
for smpl in subsample:
    node_coords[smpl.get("id_node")] = shapely.points(smpl.get("coords"))

node_coords
# Out:
# {'a0bd658a-d93f-4901-b347-37e2ac5b2156': <POINT Z (933232.695 -258386.275 2242.046)>,
#  '542ee469-28aa-4b02-b8cf-86200a4f0d80': <POINT Z (933124.225 -258248.129 2243.5)>}

# %%
node_coords
# Out:
# {'a0bd658a-d93f-4901-b347-37e2ac5b2156': <POINT Z (933232.695 -258386.275 2242.046)>,
#  '542ee469-28aa-4b02-b8cf-86200a4f0d80': <POINT Z (933124.225 -258248.129 2243.5)>}

# %%
start_point
# Out:
# (933124.224787, -258248.129494, 2243.5)

# %%
end_point
# Out:
# (933200.487623, -258390.790477, 2239.36)

# %%
run_points
# Out:
# [<POINT Z (933124.225 -258248.129 2243.5)>,
#  <POINT Z (933115.9 -258282.544 2236.75)>,
#  <POINT Z (933116.959 -258296.869 2234.75)>,
#  <POINT Z (933123.929 -258312.68 2234.44)>,
#  <POINT Z (933136.112 -258329.726 2235.12)>,
#  <POINT Z (933152.939 -258343.787 2235.68)>,
#  <POINT Z (933189.201 -258376.25 2238.44)>,
#  <POINT Z (933200.082 -258381.763 2239.36)>,
#  <POINT Z (933202.259 -258384.486 2239.36)>,
#  <POINT Z (933201.974 -258387.683 2239.36)>,
#  <POINT Z (933200.488 -258390.79 2239.36)>]

# %%
subsample # 933232.6950008888, -258386.27479766667, 2242.0455555555554    933124.224787, -258248.129494, 2243.5

# %%
for id_node in list(node_coords.keys()):
    distance = []
    for point in run_points:
        distance.append(node_coords.get(id_node).distance(point))
    min_index = distance.index(min(distance))
    node_coords[id_node] = run_points[min_index]

node_coords
# Out:
# {'a0bd658a-d93f-4901-b347-37e2ac5b2156': <POINT Z (933202.259 -258384.486 2239.36)>,
#  '542ee469-28aa-4b02-b8cf-86200a4f0d80': <POINT Z (933124.225 -258248.129 2243.5)>}

# %%
def check_shape(run_points, start_point, end_point):
    issues = []
    run_points_revised = []
    sort = False
    max_elevation = max([x.coords[0][2] for x in run_points])
    min_elevation = min([x.coords[0][2] for x in run_points])
    if start_point[2] >= end_point[2]:
        # runs that are going downwards from start to end point
        for point in run_points:
            if point.coords[0][2] < start_point[2] and point.coords[0][2] < end_point[2]:
                issues.append("U")

            elif point.coords[0][2] > start_point[2] and "U" not in issues:
                issues.append("reversedU")

        if "U" not in issues and "reversedU" not in issues:
            # normal run only going downwards
            sort = True
            run_points_revised = run_points
            start_point_revised = start_point
            end_point_revised = end_point

        if "reversedU" in issues:
            # assigns value higher than max to point before max value 
            n_points_to_revise = len(issues)
            top_reached = False
            for point in run_points:
                if top_reached == False:
                    if point.coords[0][2] < max_elevation:
                        diff = max_elevation - point.coords[0][2]
                        point_revised = (point.coords[0][0], point.coords[0][1], point.coords[0][2] + diff + n_points_to_revise)
                        n_points_to_revise -= 1

                    elif point.coords[0][2] == max_elevation:
                        top_reached = True
                        point_revised = point.coords[0]
                else:
                    point_revised = point.coords[0]

                run_points_revised.append(shapely.points(point_revised))

            start_point_revised = run_points_revised[0]
            end_point_revised = end_point

        if "U" in issues:
            # assign values lower than min to points after min value
            bottom_reached = False
            counter = 1
            for point in run_points:
                if bottom_reached == True:
                    diff = point.coords[0][2] - min_elevation
                    point_revised = (point.coords[0][0], point.coords[0][1], point.coords[0][2] - diff - counter)
                    counter += 1

                elif bottom_reached == False and point.coords[0][2] == min_elevation:
                    bottom_reached = True
                    point_revised = point.coords[0]

                else:
                    point_revised = point.coords[0]

                run_points_revised.append(shapely.points(point_revised))

            start_point_revised = start_point
            end_point_revised = run_points_revised[-1]

    return run_points_revised, start_point_revised, end_point_revised, sort

# %%
# checks if another point than start point has highes elevation
def tow_sided_run(run_points, start_point):
    issues = []
    max_elevation = max([x.coords[0][2] for x in run_points])
    for point in run_points:
        if point.coords[0][2] > start_point[2]:
            issues.append(True)

    if True in issues:
        run_points_revised = []
        n_points_to_revise = len(issues)
        top_reached = False
        for point in run_points:
            if top_reached == False:
                if point.coords[0][2] < max_elevation:
                    diff = max_elevation - point.coords[0][2]
                    point_revised = (point.coords[0][0], point.coords[0][1], point.coords[0][2] + diff + n_points_to_revise)
                    n_points_to_revise -= 1

                elif point.coords[0][2] == max_elevation:
                    top_reached = True
                    point_revised = point.coords[0]

            else:
                point_revised = point.coords[0]

            run_points_revised.append(shapely.points(point_revised))
            
    else:
        run_points_revised = list(run_points)

    start_point_revised = run_points_revised[0]
   
    return run_points_revised, start_point_revised.coords[0]

# %%
run_id
# Out:
# '66e1131dc689da599799d68d83deb89930319192'

# %%
#run_id = '327610f1acb523e9c5c26e69b849fb180f9939b7'

#test_ = nodes.copy()
#test = [x for x in test_ if [y for y in x.get("features") if y.get("id_connection") == run_id]]

#print(LineString(points[points.id==run_id].geometry).length)
#points[points.id==run_id].geometry.plot()


for run_id in list(start_end_points[start_end_points.connection_type == "run"].id.unique()):
    if run_id == '1841068a3096e585f54dceb9acd62f5c769df22a':
        print("passed")
    start_point = start_end_points[(start_end_points.id == run_id) & (start_end_points.point_type == "start")].geometry.any().coords[0]
    end_point = start_end_points[(start_end_points.id == run_id) & (start_end_points.point_type == "end")].geometry.any().coords[0]
    subsample = [x for x in nodes if [y for y in x.get("features") if y.get("id_connection") == run_id]]
    subsample_sorted = sorted(subsample, key=lambda x: x.get("coords")[2], reverse=True)

    run_points = points[points.id == run_id].geometry
    length_run = LineString(run_points).length
    run_points, start_point = tow_sided_run(run_points, start_point)
    length_segments = []

    if len(subsample_sorted) > 1:

        for i in range(1, len(subsample_sorted)):
            run_segment = []
            for point in run_points:
                if point.coords[0][2] <= start_point[2] and point.coords[0][2] >= subsample_sorted[i].get("coords")[2]:
                    run_segment.append(point)
            
            if len(run_segment) < 2 and length_run < 20:
                length_segments.append(length_run)
            else:
                length_segment = LineString(run_segment).length
                length_run = length_run - length_segment
                start_point = subsample_sorted[i].get("coords")
                length_segments.append(length_segment)

        length_segments.append(length_run)

    elif len(subsample_sorted) == 1:
        length_segments.append(length_run)


    length_run = LineString(run_points).length
    counter = 0

    for node in subsample_sorted:
        for feature in node.get("features"):
            if feature.get("id_connection") == run_id:
                feature["segment_lenght"] = length_segments[counter]
                feature["segment_proportion"] = length_segments[counter] / length_run
        counter += 1
# Out:
# passed
# ---------------------------------------------------------------------------
# GEOSException                             Traceback (most recent call last)
# Cell In[493], line 34
#      32     length_segments.append(length_run)
#      33 else:
# ---> 34     length_segment = LineString(run_segment).length
#      35     length_run = length_run - length_segment
#      36     start_point = subsample_sorted[i].get("coords")
#
# File ~/VirtualEnvironments/SkiNavApp/lib/python3.10/site-packages/shapely/geometry/linestring.py:73, in LineString.__new__(self, coordinates)
#      68 if len(coordinates) == 0:
#      69     # empty geometry
#      70     # TODO better constructor + should shapely.linestrings handle this?
#      71     return shapely.from_wkt("LINESTRING EMPTY")
# ---> 73 geom = shapely.linestrings(coordinates)
#      74 if not isinstance(geom, LineString):
#      75     raise ValueError("Invalid values passed to LineString constructor")
#
# File ~/VirtualEnvironments/SkiNavApp/lib/python3.10/site-packages/shapely/decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File ~/VirtualEnvironments/SkiNavApp/lib/python3.10/site-packages/shapely/creation.py:119, in linestrings(coords, y, z, indices, out, **kwargs)
#     117 coords = _xyz_to_coords(coords, y, z)
#     118 if indices is None:
# --> 119     return lib.linestrings(coords, out=out, **kwargs)
#     120 else:
#     121     return simple_geometries_1d(coords, indices, GeometryType.LINESTRING, out=out)
#
# GEOSException: IllegalArgumentException: point array must contain 0 or >1 elements

# %%
run_id = 'f8b504cf58e9643370192bc078ff603cb80efbc9'

test_ = nodes.copy()
test = [x for x in test_ if [y for y in x.get("features") if y.get("id_connection") == run_id]]

print(LineString(points[points.id==run_id].geometry).length)
points[points.id==run_id].geometry.plot()



start_point = start_end_points[(start_end_points.id == run_id) & (start_end_points.point_type=="start")].geometry.any().coords[0]
subsample = [x for x in test if [y for y in x.get("features") if y.get("id_connection") == run_id]]
subsample_sorted = sorted(subsample, key=lambda x: x.get("coords")[2], reverse=True)

run_points = points[points.id== run_id].geometry
length_run = LineString(run_points).length
run_points, start_point = tow_sided_run(run_points, start_point)
length_segments = []

if len(subsample_sorted) > 1:

    for i in range(1, len(subsample_sorted)):
        run_segment = []

        print(start_point[2])
        for point in run_points:
            if point.coords[0][2] <= start_point[2] and point.coords[0][2] >= subsample_sorted[i].get("coords")[2]:
                run_segment.append(point)
                print(point)
        length_segment = LineString(run_segment).length
        length_run = length_run - length_segment
        start_point = subsample_sorted[i].get("coords")
        length_segments.append(length_segment)
        print(length_segment)
        print(length_run)
        print("****")

    length_segments.append(length_run)

elif len(subsample_sorted) == 1:
    length_segments.append(length_run)


length_run = LineString(run_points).length
counter = 0

for node in subsample_sorted:
    for feature in node.get("features"):
        if feature.get("id_connection") == run_id:
            feature["segment_lenght"] = length_segments[counter]
            feature["segment_proportion"] = length_segments[counter] / length_run
    counter += 1

length_segments
# Out:
# 1372.553602280696
# (934684.326142, -258828.552163, 2557.09)
# (934684.326142, -258828.552163, 2566.13)
# 2566.13
# POINT Z (934684.326142 -258828.552163 2566.13)
# POINT Z (934687.165728 -258829.317781 2565.13)
# POINT Z (934703.565742 -258833.780126 2564.13)
# POINT Z (934685.973286 -258847.229122 2562.13)
# POINT Z (934670.245626 -258852.426223 2558.95)
# POINT Z (934629.507202 -258852.163563 2552.06)
# 99.38491571392024
# 1273.1686865667757
# ****
# 2552.06
# POINT Z (934629.507202 -258852.163563 2552.06)
# POINT Z (934624.59956 -258841.571843 2551.06)
# POINT Z (934598.498477 -258816.131382 2542.85)
# POINT Z (934598.686808 -258814.725808 2542.85)
# POINT Z (934600.917213 -258797.336098 2541.43)
# POINT Z (934593.504458 -258768.350273 2536.8)
# POINT Z (934567.262143 -258746.81233 2527.77)
# 130.93990142069194
# 1142.2287851460837
# ****
# 2526.77
# POINT Z (934551.770233 -258743.637414 2525.77)
# POINT Z (934535.162736 -258775.900776 2524.68)
# POINT Z (934519.632315 -258794.198603 2523.98)
# POINT Z (934492.876736 -258809.001982 2516.11)
# POINT Z (934469.452007 -258817.657847 2511.11)
# POINT Z (934462.377114 -258820.557458 2508.24)
# POINT Z (934454.634178 -258829.197264 2506.85)
# POINT Z (934455.929255 -258843.60894 2507.85)
# POINT Z (934459.49367 -258872.388389 2510.11)
# POINT Z (934454.093242 -258896.831392 2509.02)
# POINT Z (934453.467582 -258920.044807 2510.14)
# POINT Z (934448.291518 -258936.194861 2508.23)
# 243.76791012271843
# 898.4608750233654
# ****
# [99.38491571392024, 130.93990142069194, 243.76791012271843, 898.4608750233654]

# %%
#data = [x for x in nodes if [y for y in x.get("features") if y.get("id_connection") in ['0e97a8ce-a104-4a53-9635-eaf599ab062a', '41aa7c54-1351-439c-989d-6b391d08ad7a', '77c47ed9-fa78-4caf-ab25-3651aff9d4de']]]

data = [x for x in nodes_no_duplicates if x.get("id_node")=='a0bd658a-d93f-4901-b347-37e2ac5b2156']
data_2 = [x for x in nodes_no_duplicates if x.get("id_node") in ['542ee469-28aa-4b02-b8cf-86200a4f0d80'
]]
fig, ax = plt.subplots(figsize=(10,12))
test_data.geometry.plot(ax=ax)
start_end_points.geometry.plot(ax=ax, color="lightgreen")
gpd.GeoDataFrame(data, geometry=[Point(x.get("coords")) for x in data]).plot(ax=ax, color="red")
gpd.GeoDataFrame(data_2, geometry=[Point(x.get("coords")) for x in data_2]).plot(ax=ax, color="blue")
# Out:
# <Axes: >

# %%
data = [x for x in nodes if x.get("id_node")=="0e97a8ce-a104-4a53-9635-eaf599ab062a"]
data_2 = [x for x in nodes if x.get("id_node") in ['41aa7c54-1351-439c-989d-6b391d08ad7a',
   '77c47ed9-fa78-4caf-ab25-3651aff9d4de',
   '77c47ed9-fa78-4caf-ab25-3651aff9d4de'
]]
fig, ax = plt.subplots(figsize=(10,12))
test_data.geometry.plot(ax=ax)
start_end_points.geometry.plot(ax=ax, color="lightgreen")
gpd.GeoDataFrame(data, geometry=[Point(x.get("coords")) for x in data]).plot(ax=ax, color="red")
gpd.GeoDataFrame(data_2, geometry=[Point(x.get("coords")) for x in data_2]).plot(ax=ax, color="blue")
# Out:
# <Axes: >

# %%
data = [x for x in nodes if x.get("id_node")=='5df5b08c-4585-46b2-a270-01544f88033d']
data_2 = [x for x in nodes if x.get("id_node") in ['c6769e46-f383-4394-be03-dc142b259978',
   'efb19621-52e6-43f2-8e11-a91c48a65830'
]]
fig, ax = plt.subplots(figsize=(10,12))
test_data.geometry.plot(ax=ax)
start_end_points.geometry.plot(ax=ax, color="lightgreen")
gpd.GeoDataFrame(data, geometry=[Point(x.get("coords")) for x in data]).plot(ax=ax, color="red")
gpd.GeoDataFrame(data_2, geometry=[Point(x.get("coords")) for x in data_2]).plot(ax=ax, color="blue")
# Out:
# <Axes: >

# %%
data = [x for x in nodes if x.get("id_node")=='85bc9ef8-5a68-474d-91df-46c5a41860ce']
data_2 = [x for x in nodes if x.get("id_node") in ['62af0ac1-a554-463c-82d9-87a37499f120',
   '8b0b1b6c-aa74-4d43-92a6-8f915de15342'

]]
fig, ax = plt.subplots(figsize=(10,12))
test_data.geometry.plot(ax=ax)
start_end_points.geometry.plot(ax=ax, color="lightgreen")
gpd.GeoDataFrame(data, geometry=[Point(x.get("coords")) for x in data]).plot(ax=ax, color="red")
gpd.GeoDataFrame(data_2, geometry=[Point(x.get("coords")) for x in data_2]).plot(ax=ax, color="blue")
# Out:
# <Axes: >

# %%
data = [x for x in nodes if x.get("id_node")=='7ce44cf0-de0a-4ce7-8067-e02e60b8cdab']
data_2 = [x for x in nodes if x.get("id_node") in ['8b0b1b6c-aa74-4d43-92a6-8f915de15342',
   'c6769e46-f383-4394-be03-dc142b259978'
]]
fig, ax = plt.subplots(figsize=(10,12))
test_data.geometry.plot(ax=ax)
start_end_points.geometry.plot(ax=ax, color="lightgreen")
gpd.GeoDataFrame(data, geometry=[Point(x.get("coords")) for x in data]).plot(ax=ax, color="red")
gpd.GeoDataFrame(data_2, geometry=[Point(x.get("coords")) for x in data_2]).plot(ax=ax, color="blue")
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10,12))
test_data.geometry.plot(ax=ax)
start_end_points.geometry.plot(ax=ax, color="lightgreen")
geo_data[geo_data.id_node.isin(["e47e0245-820e-4fcc-8497-38b9e11ca099"])].plot(ax=ax, color="red")
# Out:
# /var/folders/bz/74yvks6s0yz7n9zj0lsbwc0w0000gn/T/ipykernel_809/1426704743.py:4: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   geo_data[geo_data.id_node.isin(["e47e0245-820e-4fcc-8497-38b9e11ca099"])].plot(ax=ax, color="red")
# <Axes: >

# %%
len(nodes)
# Out:
# 25

# %%
def get_center(nodes):
    x, y, z, n = [0, 0, 0, 0]
    for x_, y_, z_ in [n for n in nodes]:
        x += x_
        y += y_
        z += z_
        n += 1
    return ((x/n), (y/n), (z/n))

# %%
nodes_no_duplicates = []
discared_nodes = []
for node in nodes:
    if node.get("id_node") not in discared_nodes:
        duplicate = False
        duplactes_connections = []
        duplactes_coords = []
        for n in nodes:
            if node.get("id_node") != n.get("id_node") and shapely.points(node.get("coords")).distance(shapely.points(n.get("coords"))) < 50:
                duplactes_connections.append(n.get("id_connection")) 
                duplactes_coords.append(n.get("coords"))
                discared_nodes.append(n.get("id_node"))
                duplicate = True

        if duplicate == True:
            nodes_no_duplicates.append({"id_node": node.get("id_node"),
                                        "id_connection": list(np.unique(node.get("id_connection") + sum(duplactes_connections, []))),
                                        "coords": get_center([node.get("coords")] + duplactes_coords)})

        elif duplicate == False:
            nodes_no_duplicates.append({"id_node": node.get("id_node"),
                                        "id_connection": node.get("id_connection"),
                                        "coords": node.get("coords")})

nodes_no_duplicates
# Out:
# [{'id_node': 'aa55dd77-fbfb-4603-8d59-fea36bf03149',
#   'id_connection': ['b2cbfe63c2b8626311d669bc02a94b0bee680e1d'],
#   'coords': (933712.638106, -258556.3819655, 2292.4849999999997)},
#  {'id_node': '63498095-e026-4312-8eb1-8a1e1e959455',
#   'id_connection': ['0602c22d0ee93ab4320c45ce4d9d3cea5b49f867',
#    '20432332cc7a714c671e4105235d1ce2a757f8cc',
#    '327610f1acb523e9c5c26e69b849fb180f9939b7',
#    'dd7dbf17741e75c3decec2c7aa2770f792fad61a'],
#   'coords': (936250.20568525, -258689.75490174998, 2921.8849999999998)},
#  {'id_node': '49c145fc-0334-477a-a1c8-cc7bc703f316',
#   'id_connection': ['1744840abdd56aca2391499c8df2c252f1ca31ae',
#    '9a242f8d210edc568f6e2df202c03fc1a6ec406d'],
#   'coords': (934135.107987, -257245.82739, 2577.0)},
#  {'id_node': '0d5284b5-4590-4336-91ad-8d7f27e178bd',
#   'id_connection': ['5a8e7b947edaa619fe03e2bce9326a9fa8fdfa33',
#    'a1ce835ad3b70417de259f36d9e752aee5a3c45f'],
#   'coords': (934894.5608045, -258385.6026265, 2581.685)},
#  {'id_node': 'd8d1da03-8abe-435e-812f-f0d95ab1ddf9',
#   'id_connection': ['0a08b41aa177470635ed024b47f553f880ccd33c',
#    '1744840abdd56aca2391499c8df2c252f1ca31ae',
#    '8ca54533ba58833bb34bf182c41401bcc6ff564e'],
#   'coords': (933505.6629013333, -258011.36473433336, 2324.8366666666666)},
#  {'id_node': '7499b942-ea8f-423f-837f-b39568384e0c',
#   'id_connection': ['b2cbfe63c2b8626311d669bc02a94b0bee680e1d',
#    'c7ca163eb881f3d186a5467f6f5be8a102a4f1d5'],
#   'coords': (934015.79040675, -258563.7039595, 2332.545)},
#  {'id_node': 'ef2559b6-2a20-470d-9d32-9e10d13ce49a',
#   'id_connection': ['f9214995594b42205bf550a2ea2433ae66a4dbd0',
#    '20432332cc7a714c671e4105235d1ce2a757f8cc'],
#   'coords': (935772.8631140001, -259123.0162245, 2858.29)},
#  {'id_node': '15cd023b-085e-40e4-95b4-189ee132cead',
#   'id_connection': ['6acb68b760f81ca552ed986da7908b70d14fc098',
#    'a1ce835ad3b70417de259f36d9e752aee5a3c45f'],
#   'coords': (935222.470154, -258326.898413, 2685.56)},
#  {'id_node': '9c40ab67-b281-4d9e-8c75-0b80012819ec',
#   'id_connection': ['0602c22d0ee93ab4320c45ce4d9d3cea5b49f867',
#    '97d7066b4dd04376cb265f523855b17fbcee2142',
#    'b2cbfe63c2b8626311d669bc02a94b0bee680e1d'],
#   'coords': (934172.0093267779, -258567.48011233332, 2361.866666666667)},
#  {'id_node': '9b4aa1f3-c27b-49b0-836f-8a80215358fc',
#   'id_connection': ['0f97ef46ec9cef8503ba11c87a727bea6be0d4fe'],
#   'coords': (934629.507202, -258852.163563, 2552.06)},
#  {'id_node': '42de9e64-0428-40c9-bfcd-d691f1dfa2cb',
#   'id_connection': ['f56bbf366faa47c2109862db0d76a833c120df56',
#    '327610f1acb523e9c5c26e69b849fb180f9939b7'],
#   'coords': (936270.2815145, -258366.70822, 2841.29)},
#  {'id_node': '6124157e-730b-463a-8c59-6a27f14447fe',
#   'id_connection': ['04ec136065b5cf4a00a353745d389a1139a07674',
#    '11effb194edfdc7596d7fbcc4d28fe2fa13dee65',
#    '4c8d28e91232c0842a7ee27b6b688f83e36871c1',
#    'bf75c38fd2d0d44d9990ff17546888610fa6bca2'],
#   'coords': (934708.8294200625, -258829.0708935, 2561.3)},
#  {'id_node': 'f3f34ce8-6084-4cb7-8a30-7357ef2ced60',
#   'id_connection': ['97d7066b4dd04376cb265f523855b17fbcee2142'],
#   'coords': (934551.770233, -258743.637414, 2525.77)},
#  {'id_node': 'b40669e8-71cf-4e68-a5dc-88f3e95f5b33',
#   'id_connection': ['a1ce835ad3b70417de259f36d9e752aee5a3c45f',
#    'a0bb99c174db2bf009db1d1dbf8b918fe0a16b4a'],
#   'coords': (935429.8890114999, -258135.3978945, 2748.61)},
#  {'id_node': '1749744b-6406-4314-8f3e-372ae684f2f1',
#   'id_connection': ['a0bb99c174db2bf009db1d1dbf8b918fe0a16b4a',
#    'bf75c38fd2d0d44d9990ff17546888610fa6bca2',
#    'f56bbf366faa47c2109862db0d76a833c120df56'],
#   'coords': (935681.4238885556, -258158.67407344445, 2761.201111111111)},
#  {'id_node': '1b925383-6b2a-4b85-a072-62ecc2aa8043',
#   'id_connection': ['45080627d3faec5a150fbccff7fcd193a28e1942',
#    '1744840abdd56aca2391499c8df2c252f1ca31ae'],
#   'coords': (934024.151792, -257413.427539, 2533.84)},
#  {'id_node': 'c532e957-5a27-4a29-a77f-ce25d1811bc8',
#   'id_connection': ['0602c22d0ee93ab4320c45ce4d9d3cea5b49f867',
#    '327610f1acb523e9c5c26e69b849fb180f9939b7',
#    '4c8d28e91232c0842a7ee27b6b688f83e36871c1',
#    'bf75c38fd2d0d44d9990ff17546888610fa6bca2'],
#   'coords': (935432.334040625, -258541.65687412498, 2628.4662500000004)},
#  {'id_node': '1df0759d-4bbf-4ea6-aca1-865516194907',
#   'id_connection': ['7d2f5218911e9c0157058ab41bcc0baecd9d1b92',
#    '1744840abdd56aca2391499c8df2c252f1ca31ae'],
#   'coords': (934005.118721, -257302.837794, 2544.315)},
#  {'id_node': '05b7c076-4782-4288-bdcf-5da8f30d6eed',
#   'id_connection': ['f5bd0831bd8b7a3724442729195fbfe2aa291213',
#    'a0bb99c174db2bf009db1d1dbf8b918fe0a16b4a'],
#   'coords': (935595.031215, -258177.68438350002, 2749.37)},
#  {'id_node': '0c9255ed-9c97-4422-87eb-24389cce8fab',
#   'id_connection': ['0f97ef46ec9cef8503ba11c87a727bea6be0d4fe'],
#   'coords': (934368.2460159999, -259016.8423355, 2493.965)},
#  {'id_node': '66e203bc-3bcf-4c02-b7f4-a4f7e811e8e6',
#   'id_connection': ['8ca54533ba58833bb34bf182c41401bcc6ff564e'],
#   'coords': (933123.9826705, -257955.83451299998, 2306.385)},
#  {'id_node': '5b73d276-f87b-4cf1-bd8c-7be61e01f7fd',
#   'id_connection': ['04ec136065b5cf4a00a353745d389a1139a07674',
#    '0602c22d0ee93ab4320c45ce4d9d3cea5b49f867',
#    '5a8e7b947edaa619fe03e2bce9326a9fa8fdfa33'],
#   'coords': (934792.9975831667, -258564.03818016668, 2536.8466666666664)},
#  {'id_node': '369cb12e-d963-4fc0-9020-868da776645b',
#   'id_connection': ['a1ce835ad3b70417de259f36d9e752aee5a3c45f',
#    '45080627d3faec5a150fbccff7fcd193a28e1942'],
#   'coords': (934196.995608, -258424.43106833333, 2375.023333333333)},
#  {'id_node': '91caa4ad-b7da-4cde-9f74-799ace9a2922',
#   'id_connection': ['a1ce835ad3b70417de259f36d9e752aee5a3c45f',
#    '45080627d3faec5a150fbccff7fcd193a28e1942'],
#   'coords': (934037.1280445, -258439.16117650003, 2331.3199999999997)},
#  {'id_node': '85eebc20-478d-496a-a0be-73b55400bfc6',
#   'id_connection': ['45080627d3faec5a150fbccff7fcd193a28e1942'],
#   'coords': (934325.115906, -258216.6991635, 2457.255)},
#  {'id_node': '3a8a309b-dace-43e6-a8d7-a23d388d7801',
#   'id_connection': ['0a08b41aa177470635ed024b47f553f880ccd33c'],
#   'coords': (933278.1832725, -258011.0250355, 2298.02)}]

# %%
fig, ax = plt.subplots(figsize=(10,12))
test_data.geometry.plot(ax=ax)
start_end_points.geometry.plot(ax=ax, color="lightgreen")
gpd.GeoDataFrame(nodes, geometry=[Point(x.get("coords")) for x in nodes]).plot(ax=ax, color="red")
# Out:
# <Axes: >
